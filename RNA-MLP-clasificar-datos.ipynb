# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import os
import csv

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demoIA/datos/'  #@param {type:"string"}
# Out:
# Mounted at /content/gdrive

# %%
## selección de los parámetros

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases

#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)


# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = True #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler":
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler":
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler":
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler":
    scaler = preprocessing.RobustScaler()

  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])
# Out:
# 10 primeros datos de Entrada antes de normalizar:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
#
#
# 10 primeros datos de Entrada después de normalizar:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]
#  [-1.50652052  0.10644536 -1.2844067  -1.31297673]
#  [-1.02184904  1.26346019 -1.3412724  -1.31297673]
#  [-0.53717756  1.95766909 -1.17067529 -1.05003079]
#  [-1.50652052  0.80065426 -1.3412724  -1.18150376]
#  [-1.02184904  0.80065426 -1.2844067  -1.31297673]
#  [-1.74885626 -0.35636057 -1.3412724  -1.31297673]
#  [-1.14301691  0.10644536 -1.2844067  -1.4444497 ]]

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  to_categorical(y_train)
y_testEnc =  to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 34
#      Virginica [ 3 ]: 35
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 16
#      Virginica [ 3 ]: 15

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
rna_cant_neuronas_capas_ocultas = '20' #@param {type:"string"}
# markdown   - Nota: 'D' indica capa Drop-Out y 'BN' indica capa Batch-Normalization
rna_tipo_capa_salida = 'lineal-Numero' # param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento =  50#@param {type:"integer"}

# define tamaño de datos de entrada
num_inputs = x_train.shape[1]

# cantidad de neuronas ocultas
#hidden_layers = [ num_inputs*3//4, num_inputs//2 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] ")," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida:
# [ 4 ['20'] Dense[1]   ]

# %%
#@title Establecer modelo

opt_tipo = "Gradiente Decreciente" # param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.01 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1
for val_hid in hidden_layers:

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  3  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 4)]               0
#
#  hidd_1 (Dense)              (None, 20)                100
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False # param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train,
                                       (y_trainEnc if tipo_output_softMax else y_train),
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas,
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr )

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/50
# 3/3 [==============================] - 1s 130ms/step - loss: 4.6867 - accuracy: 0.0645 - val_loss: 2.1551 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.9671 - accuracy: 0.0000e+00 - val_loss: 1.7468 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9980 - accuracy: 0.0000e+00 - val_loss: 1.3992 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.3973 - accuracy: 0.0000e+00 - val_loss: 1.0723 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9893 - accuracy: 0.0000e+00 - val_loss: 0.7843 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6769 - accuracy: 0.0108 - val_loss: 0.5705 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4722 - accuracy: 0.0215 - val_loss: 0.4062 - val_accuracy: 0.0909
# Epoch 8/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3262 - accuracy: 0.0538 - val_loss: 0.2936 - val_accuracy: 0.2727
# Epoch 9/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2292 - accuracy: 0.1183 - val_loss: 0.2141 - val_accuracy: 0.5455
# Epoch 10/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1651 - accuracy: 0.2473 - val_loss: 0.1594 - val_accuracy: 0.6364
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1228 - accuracy: 0.2903 - val_loss: 0.1230 - val_accuracy: 0.6364
# Epoch 12/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0955 - accuracy: 0.3011 - val_loss: 0.0993 - val_accuracy: 0.6364
# Epoch 13/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0778 - accuracy: 0.3011 - val_loss: 0.0825 - val_accuracy: 0.6364
# Epoch 14/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0673 - accuracy: 0.3011 - val_loss: 0.0726 - val_accuracy: 0.6364
# Epoch 15/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0593 - accuracy: 0.3011 - val_loss: 0.0661 - val_accuracy: 0.6364
# Epoch 16/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0550 - accuracy: 0.3011 - val_loss: 0.0616 - val_accuracy: 0.6364
# Epoch 17/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0526 - accuracy: 0.3011 - val_loss: 0.0585 - val_accuracy: 0.6364
# Epoch 18/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0504 - accuracy: 0.3011 - val_loss: 0.0566 - val_accuracy: 0.6364
# Epoch 19/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0491 - accuracy: 0.3011 - val_loss: 0.0554 - val_accuracy: 0.6364
# Epoch 20/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0484 - accuracy: 0.3011 - val_loss: 0.0544 - val_accuracy: 0.6364
# Epoch 21/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0482 - accuracy: 0.3011 - val_loss: 0.0536 - val_accuracy: 0.6364
# Epoch 22/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0477 - accuracy: 0.3011 - val_loss: 0.0532 - val_accuracy: 0.6364
# Epoch 23/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0478 - accuracy: 0.3011 - val_loss: 0.0528 - val_accuracy: 0.6364
# Epoch 24/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0475 - accuracy: 0.3011 - val_loss: 0.0524 - val_accuracy: 0.6364
# Epoch 25/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0474 - accuracy: 0.3011 - val_loss: 0.0522 - val_accuracy: 0.6364
# Epoch 26/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0520 - val_accuracy: 0.6364
# Epoch 27/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0474 - accuracy: 0.3011 - val_loss: 0.0519 - val_accuracy: 0.6364
# Epoch 28/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0479 - accuracy: 0.3011 - val_loss: 0.0519 - val_accuracy: 0.6364
# Epoch 29/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0478 - accuracy: 0.3011 - val_loss: 0.0519 - val_accuracy: 0.6364
# Epoch 30/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0472 - accuracy: 0.3011 - val_loss: 0.0518 - val_accuracy: 0.6364
# Epoch 31/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0517 - val_accuracy: 0.6364
# Epoch 32/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0474 - accuracy: 0.3011 - val_loss: 0.0516 - val_accuracy: 0.6364
# Epoch 33/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0475 - accuracy: 0.3011 - val_loss: 0.0515 - val_accuracy: 0.6364
# Epoch 34/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0474 - accuracy: 0.3011 - val_loss: 0.0515 - val_accuracy: 0.6364
# Epoch 35/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0515 - val_accuracy: 0.6364
# Epoch 36/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0471 - accuracy: 0.3011 - val_loss: 0.0514 - val_accuracy: 0.6364
# Epoch 37/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0515 - val_accuracy: 0.6364
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0472 - accuracy: 0.3011 - val_loss: 0.0516 - val_accuracy: 0.6364
# Epoch 39/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0472 - accuracy: 0.3011 - val_loss: 0.0514 - val_accuracy: 0.6364
# Epoch 40/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0470 - accuracy: 0.3011 - val_loss: 0.0513 - val_accuracy: 0.6364
# Epoch 41/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0513 - val_accuracy: 0.6364
# Epoch 42/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0514 - val_accuracy: 0.6364
# Epoch 43/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0472 - accuracy: 0.3011 - val_loss: 0.0511 - val_accuracy: 0.6364
# Epoch 44/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0471 - accuracy: 0.3011 - val_loss: 0.0512 - val_accuracy: 0.6364
# Epoch 45/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0471 - accuracy: 0.3011 - val_loss: 0.0510 - val_accuracy: 0.6364
# Epoch 46/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0470 - accuracy: 0.3011 - val_loss: 0.0510 - val_accuracy: 0.6364
# Epoch 47/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0473 - accuracy: 0.3011 - val_loss: 0.0510 - val_accuracy: 0.6364
# Epoch 48/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0471 - accuracy: 0.3011 - val_loss: 0.0509 - val_accuracy: 0.6364
# Epoch 49/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0470 - accuracy: 0.3011 - val_loss: 0.0508 - val_accuracy: 0.6364
# Epoch 50/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0477 - accuracy: 0.3011 - val_loss: 0.0507 - val_accuracy: 0.6364
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo
    predClass = model.predict(x)

    # muestra los resultados con las imágenes
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ]

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: '
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm,
        index=['r:{:}'.format(x) for x in clases_map],
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# 4/4 [==============================] - 0s 3ms/step
# Real: Virginica / RNA: Virginica (2.9665298): ok
# Real: Virginica / RNA: Virginica (3.1300557): ok
# Real: Versicolor / RNA: Versicolor (2.206322): ok
# Real: Setosa / RNA: Setosa (0.97358066): ok
# Real: Virginica / RNA: Virginica (3.109262): ok
# Real: Virginica / RNA: Virginica (3.0228376): ok
# Real: Virginica / RNA: Virginica (2.6700366): ok
# Real: Virginica / RNA: Virginica (2.786491): ok
# Real: Setosa / RNA: Setosa (0.9307589): ok
# Real: Virginica / RNA: Virginica (2.8986247): ok
# Real: Virginica / RNA: Virginica (2.9453685): ok
# Real: Virginica / RNA: Virginica (2.7876961): ok
# Real: Setosa / RNA: Setosa (0.989484): ok
# Real: Setosa / RNA: Setosa (1.0193212): ok
# Real: Versicolor / RNA: Versicolor (2.1435478): ok
# Real: Setosa / RNA: Setosa (0.9335556): ok
# Real: Setosa / RNA: Setosa (0.9185804): ok
# Real: Versicolor / RNA: Versicolor (1.9360088): ok
# Real: Virginica / RNA: Virginica (2.7058573): ok
# Real: Setosa / RNA: Setosa (0.93111753): ok
# Real: Versicolor / RNA: Virginica (2.60532): error!
# Real: Virginica / RNA: Virginica (2.698655): ok
# Real: Virginica / RNA: Virginica (2.709516): ok
# Real: Versicolor / RNA: Versicolor (2.0564742): ok
# Real: Versicolor / RNA: Versicolor (2.0112052): ok
# Real: Setosa / RNA: Setosa (0.98930454): ok
# Real: Setosa / RNA: Setosa (0.9003522): ok
# Real: Versicolor / RNA: Versicolor (2.1661837): ok
# Real: Setosa / RNA: Setosa (0.9541333): ok
# Real: Versicolor / RNA: Versicolor (2.3205247): ok
# Real: Virginica / RNA: Virginica (2.7912786): ok
# Real: Versicolor / RNA: Versicolor (1.7957895): ok
# Real: Virginica / RNA: Virginica (2.592783): ok
# Real: Versicolor / RNA: Versicolor (2.4057312): ok
# Real: Versicolor / RNA: Versicolor (2.414991): ok
# Real: Versicolor / RNA: Versicolor (2.218948): ok
# Real: Versicolor / RNA: Versicolor (2.2721443): ok
# Real: Versicolor / RNA: Versicolor (2.1765733): ok
# Real: Virginica / RNA: Virginica (2.6893337): ok
# Real: Setosa / RNA: Setosa (1.0667372): ok
# Real: Versicolor / RNA: Versicolor (2.4734478): ok
# Real: Virginica / RNA: Virginica (3.0387535): ok
# Real: Setosa / RNA: Setosa (0.9765656): ok
# Real: Versicolor / RNA: Versicolor (2.038425): ok
# Real: Virginica / RNA: Virginica (2.877119): ok
# Real: Versicolor / RNA: Versicolor (2.184905): ok
# Real: Versicolor / RNA: Versicolor (2.4164784): ok
# Real: Virginica / RNA: Virginica (3.0589375): ok
# Real: Virginica / RNA: Virginica (2.525246): ok
# Real: Virginica / RNA: Virginica (2.897608): ok
# Real: Setosa / RNA: Setosa (1.0168833): ok
# Real: Virginica / RNA: Virginica (3.2429152): ok
# Real: Versicolor / RNA: Versicolor (2.2367058): ok
# Real: Setosa / RNA: Setosa (0.9896859): ok
# Real: Setosa / RNA: Setosa (1.0360624): ok
# Real: Versicolor / RNA: Versicolor (2.1861255): ok
# Real: Virginica / RNA: Virginica (2.5022438): ok
# Real: Virginica / RNA: Virginica (2.7697225): ok
# Real: Setosa / RNA: Setosa (1.1778679): ok
# Real: Versicolor / RNA: Versicolor (2.469699): ok
# Real: Virginica / RNA: Virginica (2.7372065): ok
# Real: Setosa / RNA: Setosa (1.0444843): ok
# Real: Versicolor / RNA: Versicolor (2.283589): ok
# Real: Versicolor / RNA: Versicolor (2.2303548): ok
# Real: Setosa / RNA: Setosa (0.70365787): ok
# Real: Virginica / RNA: Virginica (2.6317143): ok
# Real: Versicolor / RNA: Versicolor (2.2768426): ok
# Real: Setosa / RNA: Setosa (0.88557875): ok
# Real: Setosa / RNA: Setosa (0.9205483): ok
# Real: Virginica / RNA: Virginica (2.8784146): ok
# Real: Virginica / RNA: Virginica (2.8069785): ok
# Real: Setosa / RNA: Setosa (0.92551506): ok
# Real: Versicolor / RNA: Versicolor (2.0391877): ok
# Real: Setosa / RNA: Setosa (0.90615654): ok
# Real: Setosa / RNA: Setosa (0.92354715): ok
# Real: Virginica / RNA: Virginica (2.8115654): ok
# Real: Setosa / RNA: Setosa (0.7802527): ok
# Real: Setosa / RNA: Setosa (0.92354715): ok
# Real: Versicolor / RNA: Versicolor (2.25215): ok
# Real: Setosa / RNA: Setosa (1.0451427): ok
# Real: Versicolor / RNA: Versicolor (2.15132): ok
# Real: Setosa / RNA: Setosa (0.98367953): ok
# Real: Setosa / RNA: Setosa (0.93775976): ok
# Real: Virginica / RNA: Virginica (2.7537453): ok
# Real: Setosa / RNA: Setosa (0.8912716): ok
# Real: Virginica / RNA: Virginica (3.0093865): ok
# Real: Setosa / RNA: Setosa (1.1464441): ok
# Real: Versicolor / RNA: Versicolor (1.9083188): ok
# Real: Versicolor / RNA: Versicolor (2.2861023): ok
# Real: Setosa / RNA: Setosa (0.9474007): ok
# Real: Setosa / RNA: Setosa (0.94663805): ok
# Real: Versicolor / RNA: Versicolor (2.3629894): ok
# Real: Setosa / RNA: Setosa (1.0330774): ok
# Real: Setosa / RNA: Setosa (0.9928502): ok
# Real: Virginica / RNA: Virginica (2.6282244): ok
# Real: Versicolor / RNA: Versicolor (2.3453968): ok
# Real: Virginica / RNA: Virginica (3.0002036): ok
# Real: Virginica / RNA: Virginica (2.733915): ok
# Real: Versicolor / RNA: Versicolor (1.9449774): ok
# Real: Virginica / RNA: Virginica (3.047238): ok
# Real: Virginica / RNA: Virginica (2.7613156): ok
# Real: Versicolor / RNA: Versicolor (2.1538486): ok
# Real: Versicolor / RNA: Versicolor (2.1915474): ok
# Real: Setosa / RNA: Setosa (0.85013926): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       1.00      0.97      0.99        34
#    Virginica       0.97      1.00      0.99        35
#
#     accuracy                           0.99       104
#    macro avg       0.99      0.99      0.99       104
# weighted avg       0.99      0.99      0.99       104
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            33            1
# r:Virginica      0         0             0           35

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0520 - accuracy: 0.3261
#
# >Evaluación del Modelo:
#     - Error:  0.052012115716934204
#     - Exactitud:  32.608696818351746
#
#
#
#
# *** Resultados con datos de Prueba:
# 2/2 [==============================] - 0s 4ms/step
# Real: Versicolor / RNA: Versicolor (2.329786): ok
# Real: Setosa / RNA: Setosa (0.90766805): ok
# Real: Virginica / RNA: Virginica (2.6038976): ok
# Real: Virginica / RNA: Virginica (2.764771): ok
# Real: Setosa / RNA: Setosa (1.0221269): ok
# Real: Setosa / RNA: Setosa (0.8566698): ok
# Real: Versicolor / RNA: Versicolor (2.1126933): ok
# Real: Versicolor / RNA: Versicolor (2.033002): ok
# Real: Virginica / RNA: Virginica (2.962871): ok
# Real: Setosa / RNA: Setosa (0.94141674): ok
# Real: Setosa / RNA: Setosa (1.1167707): ok
# Real: Virginica / RNA: Virginica (2.5378718): ok
# Real: Versicolor / RNA: Versicolor (2.2845173): ok
# Real: Virginica / RNA: Virginica (2.7537453): ok
# Real: Setosa / RNA: Setosa (0.96841204): ok
# Real: Versicolor / RNA: Virginica (2.600367): error!
# Real: Virginica / RNA: Virginica (2.7623692): ok
# Real: Setosa / RNA: Setosa (0.90175056): ok
# Real: Setosa / RNA: Setosa (0.91175896): ok
# Real: Versicolor / RNA: Versicolor (2.157013): ok
# Real: Versicolor / RNA: Versicolor (2.0716286): ok
# Real: Setosa / RNA: Setosa (0.87518924): ok
# Real: Setosa / RNA: Setosa (0.8315957): ok
# Real: Virginica / RNA: Virginica (2.9360323): ok
# Real: Virginica / RNA: Virginica (2.9007182): ok
# Real: Versicolor / RNA: Versicolor (2.2757125): ok
# Real: Setosa / RNA: Setosa (0.9175633): ok
# Real: Virginica / RNA: Virginica (2.8703115): ok
# Real: Setosa / RNA: Setosa (0.8939869): ok
# Real: Versicolor / RNA: Versicolor (2.1353278): ok
# Real: Versicolor / RNA: Versicolor (1.8831556): ok
# Real: Versicolor / RNA: Versicolor (2.257193): ok
# Real: Setosa / RNA: Setosa (0.92354715): ok
# Real: Versicolor / RNA: Versicolor (2.3277292): ok
# Real: Versicolor / RNA: Versicolor (1.8284463): ok
# Real: Versicolor / RNA: Versicolor (2.0127916): ok
# Real: Virginica / RNA: Virginica (2.9266827): ok
# Real: Setosa / RNA: Setosa (1.146138): ok
# Real: Virginica / RNA: Virginica (3.1880164): ok
# Real: Virginica / RNA: Virginica (2.6953633): ok
# Real: Virginica / RNA: Virginica (2.5755718): ok
# Real: Versicolor / RNA: Versicolor (1.9373169): ok
# Real: Virginica / RNA: Virginica (2.9040468): ok
# Real: Setosa / RNA: Setosa (1.0226877): ok
# Real: Versicolor / RNA: Versicolor (2.4322927): ok
# Real: Virginica / RNA: Virginica (2.5058122): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       1.00      0.94      0.97        16
#    Virginica       0.94      1.00      0.97        15
#
#     accuracy                           0.98        46
#    macro avg       0.98      0.98      0.98        46
# weighted avg       0.98      0.98      0.98        46
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            15            1
# r:Virginica      0         0             0           15
