# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import os
import csv

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/IA/datos/'  #@param {type:"string"}
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## selección de los parámetros 

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases

#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)


# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = True #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler": 
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler": 
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler": 
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler": 
    scaler = preprocessing.RobustScaler()
  
  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])
# Out:
# 10 primeros datos de Entrada antes de normalizar:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
#
#
# 10 primeros datos de Entrada después de normalizar:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]
#  [-1.50652052  0.10644536 -1.2844067  -1.31297673]
#  [-1.02184904  1.26346019 -1.3412724  -1.31297673]
#  [-0.53717756  1.95766909 -1.17067529 -1.05003079]
#  [-1.50652052  0.80065426 -1.3412724  -1.18150376]
#  [-1.02184904  0.80065426 -1.2844067  -1.31297673]
#  [-1.74885626 -0.35636057 -1.3412724  -1.31297673]
#  [-1.14301691  0.10644536 -1.2844067  -1.4444497 ]]

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 35
#      Virginica [ 3 ]: 34
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 15
#      Virginica [ 3 ]: 16

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
rna_cant_neuronas_capas_ocultas = '240, 60, 12' #@param {type:"string"}
# markdown   - Nota: 'D' indica capa Drop-Out y 'BN' indica capa Batch-Normalization
rna_tipo_capa_salida = 'lineal-Numero' # param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento =  100#@param {type:"integer"}

# define tamaño de datos de entrada 
num_inputs = x_train.shape[1]

# cantidad de neuronas ocultas 
#hidden_layers = [ num_inputs*3//4, num_inputs//2 ] 
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )  
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )  
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] ")," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida:
# [ 4 ['240', '60', '12'] Dense[1]   ]

# %%
#@title Establecer modelo

opt_tipo = "Gradiente Decreciente" # param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.01 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for val_hid in hidden_layers:  

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  5  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 4)]               0
# _________________________________________________________________
# hidd_1 (Dense)               (None, 240)               1200
# _________________________________________________________________
# hidd_2 (Dense)               (None, 60)                14460
# _________________________________________________________________
# hidd_3 (Dense)               (None, 12)                732
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 16,405
# Trainable params: 16,405
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False # param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/100
# 3/3 [==============================] - 1s 79ms/step - loss: 2.5828 - accuracy: 0.0000e+00 - val_loss: 0.6500 - val_accuracy: 0.2727
# Epoch 2/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3154 - accuracy: 0.1828 - val_loss: 0.1600 - val_accuracy: 0.4545
# Epoch 3/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1025 - accuracy: 0.3226 - val_loss: 0.0888 - val_accuracy: 0.4545
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0781 - accuracy: 0.3226 - val_loss: 0.0713 - val_accuracy: 0.4545
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0690 - accuracy: 0.3226 - val_loss: 0.0584 - val_accuracy: 0.4545
# Epoch 6/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0620 - accuracy: 0.3226 - val_loss: 0.0475 - val_accuracy: 0.4545
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0594 - accuracy: 0.3226 - val_loss: 0.0432 - val_accuracy: 0.4545
# Epoch 8/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0531 - accuracy: 0.3226 - val_loss: 0.0350 - val_accuracy: 0.4545
# Epoch 9/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0503 - accuracy: 0.3226 - val_loss: 0.0314 - val_accuracy: 0.4545
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0503 - accuracy: 0.3226 - val_loss: 0.0325 - val_accuracy: 0.4545
# Epoch 11/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0494 - accuracy: 0.3226 - val_loss: 0.0323 - val_accuracy: 0.4545
# Epoch 12/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0548 - accuracy: 0.3226 - val_loss: 0.0322 - val_accuracy: 0.4545
# Epoch 13/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0464 - accuracy: 0.3226 - val_loss: 0.0277 - val_accuracy: 0.4545
# Epoch 14/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.3226 - val_loss: 0.0239 - val_accuracy: 0.4545
# Epoch 15/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0474 - accuracy: 0.3226 - val_loss: 0.0284 - val_accuracy: 0.4545
# Epoch 16/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0472 - accuracy: 0.3226 - val_loss: 0.0386 - val_accuracy: 0.4545
# Epoch 17/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0507 - accuracy: 0.3226 - val_loss: 0.0296 - val_accuracy: 0.4545
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0610 - accuracy: 0.3226 - val_loss: 0.0325 - val_accuracy: 0.4545
# Epoch 19/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0457 - accuracy: 0.3226 - val_loss: 0.0271 - val_accuracy: 0.4545
# Epoch 20/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0464 - accuracy: 0.3226 - val_loss: 0.0298 - val_accuracy: 0.4545
# Epoch 21/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0452 - accuracy: 0.3226 - val_loss: 0.0272 - val_accuracy: 0.4545
# Epoch 22/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0517 - accuracy: 0.3226 - val_loss: 0.0251 - val_accuracy: 0.4545
# Epoch 23/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0461 - accuracy: 0.3226 - val_loss: 0.0256 - val_accuracy: 0.4545
# Epoch 24/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0464 - accuracy: 0.3226 - val_loss: 0.0266 - val_accuracy: 0.4545
# Epoch 25/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0457 - accuracy: 0.3226 - val_loss: 0.0275 - val_accuracy: 0.4545
# Epoch 26/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0459 - accuracy: 0.3226 - val_loss: 0.0270 - val_accuracy: 0.4545
# Epoch 27/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0461 - accuracy: 0.3226 - val_loss: 0.0319 - val_accuracy: 0.4545
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0464 - accuracy: 0.3226 - val_loss: 0.0312 - val_accuracy: 0.4545
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.3226 - val_loss: 0.0251 - val_accuracy: 0.4545
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0523 - accuracy: 0.3226 - val_loss: 0.0263 - val_accuracy: 0.4545
# Epoch 31/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0462 - accuracy: 0.3226 - val_loss: 0.0313 - val_accuracy: 0.4545
# Epoch 32/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0462 - accuracy: 0.3226 - val_loss: 0.0253 - val_accuracy: 0.4545
# Epoch 33/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0457 - accuracy: 0.3226 - val_loss: 0.0265 - val_accuracy: 0.4545
# Epoch 34/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0459 - accuracy: 0.3226 - val_loss: 0.0241 - val_accuracy: 0.4545
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0495 - accuracy: 0.3226 - val_loss: 0.0307 - val_accuracy: 0.4545
# Epoch 36/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0458 - accuracy: 0.3226 - val_loss: 0.0260 - val_accuracy: 0.4545
# Epoch 37/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0451 - accuracy: 0.3226 - val_loss: 0.0241 - val_accuracy: 0.4545
# Epoch 38/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0449 - accuracy: 0.3226 - val_loss: 0.0307 - val_accuracy: 0.4545
# Epoch 39/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0445 - accuracy: 0.3226 - val_loss: 0.0257 - val_accuracy: 0.4545
# Epoch 40/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0470 - accuracy: 0.3226 - val_loss: 0.0280 - val_accuracy: 0.4545
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0463 - accuracy: 0.3226 - val_loss: 0.0252 - val_accuracy: 0.4545
# Epoch 42/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0461 - accuracy: 0.3226 - val_loss: 0.0337 - val_accuracy: 0.4545
# Epoch 43/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0476 - accuracy: 0.3226 - val_loss: 0.0297 - val_accuracy: 0.4545
# Epoch 44/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0468 - accuracy: 0.3226 - val_loss: 0.0257 - val_accuracy: 0.4545
# Epoch 45/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0446 - accuracy: 0.3226 - val_loss: 0.0276 - val_accuracy: 0.4545
# Epoch 46/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0455 - accuracy: 0.3226 - val_loss: 0.0284 - val_accuracy: 0.4545
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0450 - accuracy: 0.3226 - val_loss: 0.0260 - val_accuracy: 0.4545
# Epoch 48/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0457 - accuracy: 0.3226 - val_loss: 0.0279 - val_accuracy: 0.4545
# Epoch 49/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0462 - accuracy: 0.3226 - val_loss: 0.0269 - val_accuracy: 0.4545
# Epoch 50/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0468 - accuracy: 0.3226 - val_loss: 0.0252 - val_accuracy: 0.4545
# Epoch 51/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0449 - accuracy: 0.3226 - val_loss: 0.0253 - val_accuracy: 0.4545
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0447 - accuracy: 0.3226 - val_loss: 0.0246 - val_accuracy: 0.4545
# Epoch 53/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0469 - accuracy: 0.3226 - val_loss: 0.0322 - val_accuracy: 0.4545
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.3226 - val_loss: 0.0242 - val_accuracy: 0.4545
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0480 - accuracy: 0.3226 - val_loss: 0.0273 - val_accuracy: 0.4545
# Epoch 56/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0448 - accuracy: 0.3226 - val_loss: 0.0246 - val_accuracy: 0.4545
# Epoch 57/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0456 - accuracy: 0.3226 - val_loss: 0.0242 - val_accuracy: 0.4545
# Epoch 58/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0541 - accuracy: 0.3226 - val_loss: 0.0286 - val_accuracy: 0.4545
# Epoch 59/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0449 - accuracy: 0.3226 - val_loss: 0.0260 - val_accuracy: 0.4545
# Epoch 60/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0451 - accuracy: 0.3226 - val_loss: 0.0241 - val_accuracy: 0.4545
# Epoch 61/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0456 - accuracy: 0.3226 - val_loss: 0.0304 - val_accuracy: 0.4545
# Epoch 62/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0473 - accuracy: 0.3226 - val_loss: 0.0268 - val_accuracy: 0.4545
# Epoch 63/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0446 - accuracy: 0.3226 - val_loss: 0.0250 - val_accuracy: 0.4545
# Epoch 64/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0449 - accuracy: 0.3226 - val_loss: 0.0373 - val_accuracy: 0.4545
# Epoch 65/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0484 - accuracy: 0.3226 - val_loss: 0.0224 - val_accuracy: 0.4545
# Epoch 66/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0460 - accuracy: 0.3226 - val_loss: 0.0221 - val_accuracy: 0.4545
# Epoch 67/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0493 - accuracy: 0.3226 - val_loss: 0.0274 - val_accuracy: 0.4545
# Epoch 68/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0493 - accuracy: 0.3226 - val_loss: 0.0235 - val_accuracy: 0.4545
# Epoch 69/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0496 - accuracy: 0.3226 - val_loss: 0.0363 - val_accuracy: 0.4545
# Epoch 70/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0473 - accuracy: 0.3226 - val_loss: 0.0228 - val_accuracy: 0.4545
# Epoch 71/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 0.3226 - val_loss: 0.0264 - val_accuracy: 0.4545
# Epoch 72/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0451 - accuracy: 0.3226 - val_loss: 0.0262 - val_accuracy: 0.4545
# Epoch 73/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0455 - accuracy: 0.3226 - val_loss: 0.0258 - val_accuracy: 0.4545
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0464 - accuracy: 0.3226 - val_loss: 0.0207 - val_accuracy: 0.4545
# Epoch 75/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0536 - accuracy: 0.3226 - val_loss: 0.0312 - val_accuracy: 0.4545
# Epoch 76/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0544 - accuracy: 0.3226 - val_loss: 0.0326 - val_accuracy: 0.4545
# Epoch 77/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0448 - accuracy: 0.3226 - val_loss: 0.0287 - val_accuracy: 0.4545
# Epoch 78/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0483 - accuracy: 0.3226 - val_loss: 0.0239 - val_accuracy: 0.4545
# Epoch 79/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0458 - accuracy: 0.3226 - val_loss: 0.0254 - val_accuracy: 0.4545
# Epoch 80/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0445 - accuracy: 0.3226 - val_loss: 0.0286 - val_accuracy: 0.4545
# Epoch 81/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0450 - accuracy: 0.3226 - val_loss: 0.0267 - val_accuracy: 0.4545
# Epoch 82/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0444 - accuracy: 0.3226 - val_loss: 0.0320 - val_accuracy: 0.4545
# Epoch 83/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0454 - accuracy: 0.3226 - val_loss: 0.0268 - val_accuracy: 0.4545
# Epoch 84/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0448 - accuracy: 0.3226 - val_loss: 0.0324 - val_accuracy: 0.4545
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0475 - accuracy: 0.3226 - val_loss: 0.0299 - val_accuracy: 0.4545
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0456 - accuracy: 0.3226 - val_loss: 0.0276 - val_accuracy: 0.4545
# Epoch 87/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0448 - accuracy: 0.3226 - val_loss: 0.0254 - val_accuracy: 0.4545
# Epoch 88/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0450 - accuracy: 0.3226 - val_loss: 0.0239 - val_accuracy: 0.4545
# Epoch 89/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.3226 - val_loss: 0.0268 - val_accuracy: 0.4545
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0527 - accuracy: 0.3226 - val_loss: 0.0354 - val_accuracy: 0.4545
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0456 - accuracy: 0.3226 - val_loss: 0.0248 - val_accuracy: 0.4545
# Epoch 92/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0452 - accuracy: 0.3226 - val_loss: 0.0271 - val_accuracy: 0.4545
# Epoch 93/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0445 - accuracy: 0.3226 - val_loss: 0.0255 - val_accuracy: 0.4545
# Epoch 94/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0457 - accuracy: 0.3226 - val_loss: 0.0238 - val_accuracy: 0.4545
# Epoch 95/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0455 - accuracy: 0.3226 - val_loss: 0.0252 - val_accuracy: 0.4545
# Epoch 96/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0452 - accuracy: 0.3226 - val_loss: 0.0246 - val_accuracy: 0.4545
# Epoch 97/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0453 - accuracy: 0.3226 - val_loss: 0.0287 - val_accuracy: 0.4545
# Epoch 98/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0444 - accuracy: 0.3226 - val_loss: 0.0269 - val_accuracy: 0.4545
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0456 - accuracy: 0.3226 - val_loss: 0.0372 - val_accuracy: 0.4545
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0453 - accuracy: 0.3226 - val_loss: 0.0244 - val_accuracy: 0.4545
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5 
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real: Setosa / RNA: Setosa (0.90014243): ok
# Real: Versicolor / RNA: Versicolor (1.9459912): ok
# Real: Versicolor / RNA: Versicolor (1.9520963): ok
# Real: Setosa / RNA: Setosa (1.0152893): ok
# Real: Setosa / RNA: Setosa (1.0751677): ok
# Real: Setosa / RNA: Setosa (1.0011245): ok
# Real: Versicolor / RNA: Versicolor (2.2671514): ok
# Real: Virginica / RNA: Virginica (2.971015): ok
# Real: Versicolor / RNA: Versicolor (2.3884182): ok
# Real: Versicolor / RNA: Versicolor (2.416716): ok
# Real: Setosa / RNA: Setosa (0.825966): ok
# Real: Virginica / RNA: Virginica (2.9621181): ok
# Real: Versicolor / RNA: Versicolor (2.0174944): ok
# Real: Versicolor / RNA: Versicolor (2.0455108): ok
# Real: Virginica / RNA: Virginica (3.057239): ok
# Real: Virginica / RNA: Versicolor (2.4475775): error!
# Real: Setosa / RNA: Setosa (1.0487937): ok
# Real: Versicolor / RNA: Versicolor (2.1235723): ok
# Real: Virginica / RNA: Virginica (2.7986474): ok
# Real: Versicolor / RNA: Versicolor (2.2458959): ok
# Real: Virginica / RNA: Virginica (3.0915403): ok
# Real: Versicolor / RNA: Versicolor (1.9045762): ok
# Real: Virginica / RNA: Virginica (2.7619128): ok
# Real: Virginica / RNA: Virginica (2.7283635): ok
# Real: Virginica / RNA: Virginica (2.877617): ok
# Real: Versicolor / RNA: Versicolor (2.0470047): ok
# Real: Virginica / RNA: Virginica (2.9635577): ok
# Real: Virginica / RNA: Virginica (2.7262754): ok
# Real: Virginica / RNA: Virginica (3.0241957): ok
# Real: Virginica / RNA: Virginica (2.5920548): ok
# Real: Virginica / RNA: Virginica (2.667725): ok
# Real: Versicolor / RNA: Versicolor (2.3008509): ok
# Real: Virginica / RNA: Virginica (2.9492989): ok
# Real: Setosa / RNA: Setosa (1.0336051): ok
# Real: Setosa / RNA: Setosa (1.2072867): ok
# Real: Setosa / RNA: Setosa (0.95212626): ok
# Real: Setosa / RNA: Setosa (0.8971567): ok
# Real: Virginica / RNA: Virginica (2.9881501): ok
# Real: Virginica / RNA: Virginica (2.867062): ok
# Real: Virginica / RNA: Virginica (3.0131803): ok
# Real: Versicolor / RNA: Versicolor (2.4709673): ok
# Real: Setosa / RNA: Setosa (0.8076411): ok
# Real: Versicolor / RNA: Versicolor (2.0624979): ok
# Real: Versicolor / RNA: Versicolor (2.3595262): ok
# Real: Virginica / RNA: Virginica (3.0916734): ok
# Real: Virginica / RNA: Virginica (2.7683153): ok
# Real: Virginica / RNA: Virginica (2.832316): ok
# Real: Setosa / RNA: Setosa (1.0328536): ok
# Real: Virginica / RNA: Virginica (2.687542): ok
# Real: Versicolor / RNA: Versicolor (1.8701882): ok
# Real: Setosa / RNA: Setosa (1.034347): ok
# Real: Versicolor / RNA: Versicolor (2.163362): ok
# Real: Versicolor / RNA: Versicolor (1.9619459): ok
# Real: Versicolor / RNA: Versicolor (1.978346): ok
# Real: Versicolor / RNA: Versicolor (2.1758547): ok
# Real: Setosa / RNA: Setosa (0.9305272): ok
# Real: Setosa / RNA: Setosa (0.9305272): ok
# Real: Setosa / RNA: Setosa (0.91235256): ok
# Real: Virginica / RNA: Virginica (2.5146027): ok
# Real: Setosa / RNA: Setosa (1.0079876): ok
# Real: Virginica / RNA: Virginica (2.686502): ok
# Real: Versicolor / RNA: Versicolor (2.161736): ok
# Real: Setosa / RNA: Setosa (0.9287218): ok
# Real: Virginica / RNA: Virginica (2.927662): ok
# Real: Versicolor / RNA: Versicolor (2.173915): ok
# Real: Setosa / RNA: Setosa (1.1203042): ok
# Real: Versicolor / RNA: Versicolor (2.259138): ok
# Real: Versicolor / RNA: Versicolor (2.3724947): ok
# Real: Virginica / RNA: Virginica (2.9671836): ok
# Real: Virginica / RNA: Virginica (2.582518): ok
# Real: Setosa / RNA: Setosa (1.028242): ok
# Real: Versicolor / RNA: Versicolor (2.2721066): ok
# Real: Setosa / RNA: Setosa (0.92903435): ok
# Real: Setosa / RNA: Setosa (0.92815876): ok
# Real: Virginica / RNA: Virginica (2.8521547): ok
# Real: Setosa / RNA: Setosa (0.88554764): ok
# Real: Virginica / RNA: Virginica (2.814766): ok
# Real: Setosa / RNA: Setosa (1.1730317): ok
# Real: Setosa / RNA: Setosa (0.9305272): ok
# Real: Setosa / RNA: Setosa (0.9276983): ok
# Real: Setosa / RNA: Setosa (1.0057365): ok
# Real: Versicolor / RNA: Versicolor (2.2705975): ok
# Real: Virginica / RNA: Virginica (2.7376018): ok
# Real: Versicolor / RNA: Versicolor (1.9901103): ok
# Real: Virginica / RNA: Virginica (2.5505133): ok
# Real: Versicolor / RNA: Versicolor (2.095572): ok
# Real: Virginica / RNA: Virginica (3.0566602): ok
# Real: Versicolor / RNA: Versicolor (2.220686): ok
# Real: Setosa / RNA: Setosa (1.0218241): ok
# Real: Versicolor / RNA: Versicolor (2.1161387): ok
# Real: Virginica / RNA: Virginica (3.2193274): ok
# Real: Versicolor / RNA: Versicolor (2.2911806): ok
# Real: Setosa / RNA: Setosa (0.8742048): ok
# Real: Virginica / RNA: Virginica (2.8175893): ok
# Real: Setosa / RNA: Setosa (0.9661271): ok
# Real: Setosa / RNA: Setosa (0.92948765): ok
# Real: Setosa / RNA: Setosa (1.0449164): ok
# Real: Versicolor / RNA: Versicolor (2.2014937): ok
# Real: Setosa / RNA: Setosa (0.974765): ok
# Real: Versicolor / RNA: Versicolor (2.367875): ok
# Real: Setosa / RNA: Setosa (0.7933441): ok
# Real: Setosa / RNA: Setosa (0.7196129): ok
# Real: Versicolor / RNA: Versicolor (2.2022371): ok
# Real: Versicolor / RNA: Versicolor (2.4243379): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       0.97      1.00      0.99        35
#    Virginica       1.00      0.97      0.99        34
#
#     accuracy                           0.99       104
#    macro avg       0.99      0.99      0.99       104
# weighted avg       0.99      0.99      0.99       104
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            35            0
# r:Virginica      0         0             1           33

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 0.3261
#
# >Evaluación del Modelo:
#     - Error:  0.05866533890366554
#     - Exactitud:  32.608696818351746
#
#
#
#
# *** Resultados con datos de Prueba:
# Real: Virginica / RNA: Virginica (2.9111362): ok
# Real: Virginica / RNA: Virginica (3.170961): ok
# Real: Setosa / RNA: Setosa (0.9632898): ok
# Real: Virginica / RNA: Virginica (2.7658849): ok
# Real: Setosa / RNA: Setosa (1.0535545): ok
# Real: Versicolor / RNA: Versicolor (2.1588984): ok
# Real: Virginica / RNA: Virginica (2.7688875): ok
# Real: Virginica / RNA: Virginica (2.6474395): ok
# Real: Setosa / RNA: Setosa (0.93648446): ok
# Real: Versicolor / RNA: Versicolor (2.2749138): ok
# Real: Setosa / RNA: Setosa (0.96568143): ok
# Real: Virginica / RNA: Virginica (2.5878887): ok
# Real: Versicolor / RNA: Versicolor (2.313209): ok
# Real: Versicolor / RNA: Versicolor (2.204598): ok
# Real: Virginica / RNA: Virginica (2.683679): ok
# Real: Virginica / RNA: Virginica (2.9278626): ok
# Real: Virginica / RNA: Virginica (2.760553): ok
# Real: Virginica / RNA: Virginica (2.6808724): ok
# Real: Virginica / RNA: Virginica (2.7658849): ok
# Real: Versicolor / RNA: Versicolor (2.281479): ok
# Real: Virginica / RNA: Virginica (2.7480683): ok
# Real: Versicolor / RNA: Virginica (2.557948): error!
# Real: Virginica / RNA: Virginica (2.6775742): ok
# Real: Setosa / RNA: Setosa (1.0955714): ok
# Real: Setosa / RNA: Setosa (0.9429022): ok
# Real: Versicolor / RNA: Versicolor (2.0635302): ok
# Real: Setosa / RNA: Setosa (0.93797725): ok
# Real: Virginica / RNA: Virginica (2.5703082): ok
# Real: Virginica / RNA: Virginica (2.529829): ok
# Real: Versicolor / RNA: Versicolor (2.221733): ok
# Real: Versicolor / RNA: Versicolor (2.1444368): ok
# Real: Versicolor / RNA: Versicolor (2.3398657): ok
# Real: Setosa / RNA: Setosa (1.1238624): ok
# Real: Setosa / RNA: Setosa (0.8713983): ok
# Real: Versicolor / RNA: Versicolor (2.191496): ok
# Real: Versicolor / RNA: Versicolor (2.1411695): ok
# Real: Setosa / RNA: Setosa (0.8924036): ok
# Real: Setosa / RNA: Setosa (1.0224416): ok
# Real: Versicolor / RNA: Versicolor (2.2314181): ok
# Real: Setosa / RNA: Setosa (0.9565901): ok
# Real: Setosa / RNA: Setosa (0.90624744): ok
# Real: Setosa / RNA: Setosa (0.9157841): ok
# Real: Versicolor / RNA: Virginica (2.5805798): error!
# Real: Virginica / RNA: Virginica (2.9516602): ok
# Real: Setosa / RNA: Setosa (1.0041099): ok
# Real: Versicolor / RNA: Versicolor (2.0942276): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       1.00      0.87      0.93        15
#    Virginica       0.89      1.00      0.94        16
#
#     accuracy                           0.96        46
#    macro avg       0.96      0.96      0.96        46
# weighted avg       0.96      0.96      0.96        46
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            13            2
# r:Virginica      0         0             0           16
