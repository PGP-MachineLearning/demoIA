# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation usando Keras para procesar las imágenes de ANIMALES e identificar el tipo correspondiente

# %% [markdown]
# 1) Cargar librerías:

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import plot_model

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
# tamaño de las imágenes
IMAGE_SHAPE = (32, 32, 1)

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# define tamaño de datos de salida (las clases están codificadas en un único número)
num_outputs = 1 

# cantidad de neuronas ocultas 
hidden_layers = [ 784, 392, 56, 32 ] 

# cantidad de épocas del entrenamiento
cantEpocas = 500

print("Configuración de RNA MLP Backpropagation definida: [", num_inputs, hidden_layers, num_outputs," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida: [ 1024 [784, 392, 56, 32] 1  ]

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo ANIMALES' 
imagPath_train = path + '/imagenes/train' 
imagPath_test = path + '/imagenes/test'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:
            
            # abre la imagen
            imag = Image.open(auxiPath + "/" + each_imagFN)
            
            # ajusta el tamaño
            if IMAGE_SHAPE[2]==1:
              imag = imag.convert('L')
              tipoImage = 'L'
            else:
              tipoImage = 'RGB'
            imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
            
            # transforma a un vector de nros
            arImag = np.array(imag)
            
            # agrega a los vectores
            classes_ori.append( each_dir )
            images_ori.append( arImag )
  return classes_ori, images_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  42
# - Imágenes cargadas:  42
# - Ejemplo  invertebrado   (32, 32) :
# <PIL.Image.Image image mode=L size=32x32 at 0x7F42D2E5D780>
# > Para Prueba:
# - Clases cargadas:  18
# - Imágenes cargadas:  18
# - Ejemplo  mamifero   (32, 32) :
# <PIL.Image.Image image mode=L size=32x32 at 0x7F42D0EA3208>

# %%
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  return np.array(y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, dictMapeo = prepare_clasesList(classes_train)
y_test, _ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]], "(", y_train[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (42, 1024)
#  - y_train (cant):  42
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (18, 1024)
#  - y_test (cant):  18
#
#
# > Para Ambos:
#  - dictMapeo:  {'pez': 0, 'mamifero': 1, 'ave': 2, 'invertebrado': 3, 'insecto': 4, 'reptil': 5}
#  - clases_map:  ['pez', 'mamifero', 'ave', 'invertebrado', 'insecto', 'reptil']
#
#  - Imagen reconstruida de  invertebrado ( 3 )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for num_hid in hidden_layers:  
    
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(num_hid, name=auxlayerName)(eachLay) # capas ocultas

output_img_Lay = Dense(num_outputs, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  6  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 1024)]            0
# _________________________________________________________________
# hidd_1 (Dense)               (None, 784)               803600
# _________________________________________________________________
# hidd_2 (Dense)               (None, 392)               307720
# _________________________________________________________________
# hidd_3 (Dense)               (None, 56)                22008
# _________________________________________________________________
# hidd_4 (Dense)               (None, 32)                1824
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 1,135,185
# Trainable params: 1,135,185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
# lleva a cabo el entrenamiento
model.fit(x_train, y_train,
                epochs = cantEpocas, 
                batch_size = 10 )
# Out:
# Epoch 1/500
# 5/5 [==============================] - 0s 11ms/step - loss: 734.2734 - accuracy: 0.2143
# Epoch 2/500
# 5/5 [==============================] - 0s 9ms/step - loss: 4.3389 - accuracy: 0.1667
# Epoch 3/500
# 5/5 [==============================] - 0s 9ms/step - loss: 4.2180 - accuracy: 0.1667
# Epoch 4/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.8182 - accuracy: 0.1190
# Epoch 5/500
# 5/5 [==============================] - 0s 10ms/step - loss: 3.0240 - accuracy: 0.1667
# Epoch 6/500
# 5/5 [==============================] - 0s 8ms/step - loss: 3.6012 - accuracy: 0.1429
# Epoch 7/500
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1344 - accuracy: 0.1667
# Epoch 8/500
# 5/5 [==============================] - 0s 9ms/step - loss: 21.6182 - accuracy: 0.1905
# Epoch 9/500
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6765 - accuracy: 0.1905
# Epoch 10/500
# 5/5 [==============================] - 0s 9ms/step - loss: 7.2484 - accuracy: 0.1190
# Epoch 11/500
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9947 - accuracy: 0.1905
# Epoch 12/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.2118 - accuracy: 0.1667
# Epoch 13/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.5218 - accuracy: 0.1905
# Epoch 14/500
# 5/5 [==============================] - 0s 9ms/step - loss: 4.4205 - accuracy: 0.1429
# Epoch 15/500
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2762 - accuracy: 0.1667
# Epoch 16/500
# 5/5 [==============================] - 0s 10ms/step - loss: 3.7425 - accuracy: 0.1905
# Epoch 17/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.8135 - accuracy: 0.2143
# Epoch 18/500
# 5/5 [==============================] - 0s 9ms/step - loss: 5.4402 - accuracy: 0.1429
500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3728 - accuracy: 0.2619
# Epoch 134/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1294 - accuracy: 0.3095
# Epoch 135/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0375 - accuracy: 0.3333
# Epoch 136/500
# 5/5 [==============================] - 0s 11ms/step - loss: 4.1835 - accuracy: 0.1190
# Epoch 137/500
# 5/5 [==============================] - 0s 9ms/step - loss: 2.4028 - accuracy: 0.2857
# Epoch 138/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 0.3333
# Epoch 139/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1936 - accuracy: 0.3333
# Epoch 140/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0923 - accuracy: 0.3333
# Epoch 141/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2458 - accuracy: 0.2857
# Epoch 142/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2427 - accuracy: 0.3095
# Epoch 143/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2391 - accuracy: 0.3095
# Epoch 144/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7670 - accuracy: 0.2143
# Epoch 145/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1542 - accuracy: 0.3095
# Epoch 146/500
# 5/5 [==============================] - 0s 8ms/step - loss: 1.2913 - accuracy: 0.2143
# Epoch 147/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0156 - accuracy: 0.3095
# Epoch 148/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7037 - accuracy: 0.2143
# Epoch 149/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0941 - accuracy: 0.3333
# Epoch 150/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1082 - accuracy: 0.3333
# Epoch 151/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9016 - accuracy: 0.2143
# Epoch 152/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.4532 - accuracy: 0.1667
# Epoch 153/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3511 - accuracy: 0.2143
# Epoch 154/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1182 - accuracy: 0.3095
# Epoch 155/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9267 - accuracy: 0.2143
# Epoch 156/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1299 - accuracy: 0.3333
# Epoch 157/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3858 - accuracy: 0.2857
# Epoch 158/500
# 5/5 [==============================] - 0s 9ms/step - loss: 2.0633 - accuracy: 0.1190
# Epoch 159/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3315 - accuracy: 0.2857
# Epoch 160/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0712 - accuracy: 0.3095
# Epoch 161/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0510 - accuracy: 0.3333
# Epoch 162/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4285 - accuracy: 0.2857
# Epoch 163/500
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6314 - accuracy: 0.2381
# Epoch 164/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2445 - accuracy: 0.3333
# Epoch 165/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0971 - accuracy: 0.3333
# Epoch 166/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5610 - accuracy: 0.3095
# Epoch 167/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2108 - accuracy: 0.3333
# Epoch 168/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0740 - accuracy: 0.3333
# Epoch 169/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0858 - accuracy: 0.1429
# Epoch 170/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3080 - accuracy: 0.2857
# Epoch 171/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0393 - accuracy: 0.3095
# Epoch 172/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2891 - accuracy: 0.3095
# Epoch 173/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0401 - accuracy: 0.3333
# Epoch 174/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1537 - accuracy: 0.2857
# Epoch 175/500
# 5/5 [==============================] - 0s 10ms/step - loss: 4.0267 - accuracy: 0.1667
# Epoch 176/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.5529 - accuracy: 0.1905
# Epoch 177/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1831 - accuracy: 0.3095
# Epoch 178/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0752 - accuracy: 0.3333
# Epoch 179/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0422 - accuracy: 0.3333
# Epoch 180/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3374 - accuracy: 0.2857
# Epoch 181/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0390 - accuracy: 0.3333
# Epoch 182/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5649 - accuracy: 0.2143
# Epoch 183/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3575 - accuracy: 0.2857
# Epoch 184/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6450 - accuracy: 0.2381
# Epoch 185/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4488 - accuracy: 0.2857
# Epoch 186/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1541 - accuracy: 0.1905
# Epoch 187/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1701 - accuracy: 0.3095
# Epoch 188/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0451 - accuracy: 0.3333
# Epoch 189/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0721 - accuracy: 0.3333
# Epoch 190/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3786 - accuracy: 0.3095
# Epoch 191/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2665 - accuracy: 0.2857
# Epoch 192/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7122 - accuracy: 0.2857
# Epoch 193/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8514 - accuracy: 0.2143
# Epoch 194/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3974 - accuracy: 0.3095
# Epoch 195/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2458 - accuracy: 0.3095
# Epoch 196/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1054 - accuracy: 0.3333
# Epoch 197/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4218 - accuracy: 0.2857
# Epoch 198/500
# 5/5 [==============================] - 0s 9ms/step - loss: 2.0280 - accuracy: 0.2381
# Epoch 199/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9428 - accuracy: 0.2619
# Epoch 200/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4869 - accuracy: 0.2381
# Epoch 201/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0856 - accuracy: 0.3333
# Epoch 202/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0936 - accuracy: 0.3333
# Epoch 203/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1148 - accuracy: 0.3333
# Epoch 204/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4268 - accuracy: 0.2381
# Epoch 205/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0693 - accuracy: 0.3333
# Epoch 206/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2239 - accuracy: 0.3095
# Epoch 207/500
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0516 - accuracy: 0.1905
# Epoch 208/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1693 - accuracy: 0.3095
# Epoch 209/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0956 - accuracy: 0.3333
# Epoch 210/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3317 - accuracy: 0.3333
# Epoch 211/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0864 - accuracy: 0.3333
# Epoch 212/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0186 - accuracy: 0.3333
# Epoch 213/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1210 - accuracy: 0.3095
# Epoch 214/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2411 - accuracy: 0.3333
# Epoch 215/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.2661 - accuracy: 0.3095
# Epoch 216/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4212 - accuracy: 0.2619
# Epoch 217/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7182 - accuracy: 0.2381
# Epoch 218/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0623 - accuracy: 0.3333
# Epoch 219/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0370 - accuracy: 0.3333
# Epoch 220/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3290 - accuracy: 0.2857
# Epoch 221/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4084 - accuracy: 0.2619
# Epoch 222/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0452 - accuracy: 0.3333
# Epoch 223/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4582 - accuracy: 0.2381
# Epoch 224/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0858 - accuracy: 0.3333
# Epoch 225/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5305 - accuracy: 0.2619
# Epoch 226/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9747 - accuracy: 0.2619
# Epoch 227/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4059 - accuracy: 0.2619
# Epoch 228/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0724 - accuracy: 0.3333
# Epoch 229/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0392 - accuracy: 0.3333
# Epoch 230/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0841 - accuracy: 0.3333
# Epoch 231/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7233 - accuracy: 0.2857
# Epoch 232/500
# 5/5 [==============================] - 0s 9ms/step - loss: 4.0278 - accuracy: 0.1905
# Epoch 233/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2962 - accuracy: 0.3095
# Epoch 234/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1946 - accuracy: 0.3333
# Epoch 235/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0462 - accuracy: 0.3333
# Epoch 236/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2710 - accuracy: 0.2857
# Epoch 237/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2813 - accuracy: 0.2857
# Epoch 238/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0321 - accuracy: 0.3333
# Epoch 239/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5084 - accuracy: 0.2143
# Epoch 240/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0315 - accuracy: 0.3333
# Epoch 241/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0756 - accuracy: 0.3333
# Epoch 242/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1475 - accuracy: 0.3333
# Epoch 243/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.6241 - accuracy: 0.2381
# Epoch 244/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.2476 - accuracy: 0.2381
# Epoch 245/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0442 - accuracy: 0.3333
# Epoch 246/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0402 - accuracy: 0.3333
# Epoch 247/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0172 - accuracy: 0.3333
# Epoch 248/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0226 - accuracy: 0.3333
# Epoch 249/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0425 - accuracy: 0.3333
# Epoch 250/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8681 - accuracy: 0.2619
# Epoch 251/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4391 - accuracy: 0.2381
# Epoch 252/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0864 - accuracy: 0.3333
# Epoch 253/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2526 - accuracy: 0.2857
# Epoch 254/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1169 - accuracy: 0.3333
# Epoch 255/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5024 - accuracy: 0.2381
# Epoch 256/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.1462 - accuracy: 0.1190
# Epoch 257/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1432 - accuracy: 0.3333
# Epoch 258/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3951 - accuracy: 0.2619
# Epoch 259/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1926 - accuracy: 0.3095
# Epoch 260/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1053 - accuracy: 0.3333
# Epoch 261/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1075 - accuracy: 0.3333
# Epoch 262/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1165 - accuracy: 0.2619
# Epoch 263/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.3333
# Epoch 264/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0530 - accuracy: 0.3333
# Epoch 265/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4631 - accuracy: 0.3333
# Epoch 266/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2695 - accuracy: 0.3095
# Epoch 267/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0307 - accuracy: 0.3333
# Epoch 268/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3497 - accuracy: 0.3333
# Epoch 269/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0668 - accuracy: 0.1905
# Epoch 270/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3350 - accuracy: 0.2619
# Epoch 271/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1238 - accuracy: 0.3333
# Epoch 272/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3314 - accuracy: 0.2857
# Epoch 273/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0231 - accuracy: 0.3333
# Epoch 274/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2629 - accuracy: 0.3095
# Epoch 275/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2416 - accuracy: 0.3095
# Epoch 276/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3057 - accuracy: 0.2857
# Epoch 277/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0823 - accuracy: 0.3095
# Epoch 278/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2494 - accuracy: 0.2857
# Epoch 279/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0635 - accuracy: 0.3333
# Epoch 280/500
# 5/5 [==============================] - 0s 11ms/step - loss: 2.4294 - accuracy: 0.2619
# Epoch 281/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9150 - accuracy: 0.2143
# Epoch 282/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0900 - accuracy: 0.3333
# Epoch 283/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0206 - accuracy: 0.3333
# Epoch 284/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2722 - accuracy: 0.2857
# Epoch 285/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0778 - accuracy: 0.3333
# Epoch 286/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2088 - accuracy: 0.3095
# Epoch 287/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1449 - accuracy: 0.3095
# Epoch 288/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1240 - accuracy: 0.3333
# Epoch 289/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5059 - accuracy: 0.2381
# Epoch 290/500
# 5/5 [==============================] - 0s 10ms/step - loss: 1.5141 - accuracy: 0.2143
# Epoch 291/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1796 - accuracy: 0.2857
# Epoch 292/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0413 - accuracy: 0.3333
# Epoch 293/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0689 - accuracy: 0.3333
# Epoch 294/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0750 - accuracy: 0.3333
# Epoch 295/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3153 - accuracy: 0.3095
# Epoch 296/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5644 - accuracy: 0.2381
# Epoch 297/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8075 - accuracy: 0.2619
# Epoch 298/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0803 - accuracy: 0.3333
# Epoch 299/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0526 - accuracy: 0.3333
# Epoch 300/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0469 - accuracy: 0.3333
# Epoch 301/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0358 - accuracy: 0.3333
# Epoch 302/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3746 - accuracy: 0.2857
# Epoch 303/500
# 5/5 [==============================] - 0s 8ms/step - loss: 3.4402 - accuracy: 0.2619
# Epoch 304/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4815 - accuracy: 0.2143
# Epoch 305/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1768 - accuracy: 0.3333
# Epoch 306/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1943 - accuracy: 0.3095
# Epoch 307/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3810 - accuracy: 0.2857
# Epoch 308/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 0.3333
# Epoch 309/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2837 - accuracy: 0.3333
# Epoch 310/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0539 - accuracy: 0.3333
# Epoch 311/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1812 - accuracy: 0.3095
# Epoch 312/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3536 - accuracy: 0.2619
# Epoch 313/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4821 - accuracy: 0.2381
# Epoch 314/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1819 - accuracy: 0.3333
# Epoch 315/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1493 - accuracy: 0.3333
# Epoch 316/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1519 - accuracy: 0.3333
# Epoch 317/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.3333
# Epoch 318/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7386 - accuracy: 0.3095
# Epoch 319/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9497 - accuracy: 0.2381
# Epoch 320/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0861 - accuracy: 0.3333
# Epoch 321/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1407 - accuracy: 0.3333
# Epoch 322/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0317 - accuracy: 0.3333
# Epoch 323/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2788 - accuracy: 0.3333
# Epoch 324/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.2521 - accuracy: 0.1667
# Epoch 325/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1253 - accuracy: 0.3333
# Epoch 326/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0980 - accuracy: 0.3333
# Epoch 327/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0219 - accuracy: 0.3333
# Epoch 328/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0411 - accuracy: 0.3333
# Epoch 329/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0865 - accuracy: 0.3333
# Epoch 330/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2754 - accuracy: 0.3095
# Epoch 331/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0822 - accuracy: 0.3333
# Epoch 332/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1841 - accuracy: 0.3333
# Epoch 333/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4116 - accuracy: 0.2381
# Epoch 334/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1091 - accuracy: 0.3333
# Epoch 335/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1741 - accuracy: 0.2857
# Epoch 336/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2672 - accuracy: 0.3095
# Epoch 337/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5736 - accuracy: 0.2857
# Epoch 338/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5467 - accuracy: 0.2619
# Epoch 339/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0731 - accuracy: 0.3333
# Epoch 340/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0183 - accuracy: 0.3333
# Epoch 341/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2320 - accuracy: 0.3333
# Epoch 342/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1075 - accuracy: 0.3333
# Epoch 343/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0460 - accuracy: 0.3333
# Epoch 344/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8988 - accuracy: 0.2857
# Epoch 345/500
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1313 - accuracy: 0.2143
# Epoch 346/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1171 - accuracy: 0.2619
# Epoch 347/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1021 - accuracy: 0.3095
# Epoch 348/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0168 - accuracy: 0.3333
# Epoch 349/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0146 - accuracy: 0.3333
# Epoch 350/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0624 - accuracy: 0.3333
# Epoch 351/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0616 - accuracy: 0.3095
# Epoch 352/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3664 - accuracy: 0.2857
# Epoch 353/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3791 - accuracy: 0.3333
# Epoch 354/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1207 - accuracy: 0.3333
# Epoch 355/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.3333
# Epoch 356/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6202 - accuracy: 0.2143
# Epoch 357/500
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6021 - accuracy: 0.1905
# Epoch 358/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1033 - accuracy: 0.3333
# Epoch 359/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0397 - accuracy: 0.3333
# Epoch 360/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0538 - accuracy: 0.3333
# Epoch 361/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2370 - accuracy: 0.2857
# Epoch 362/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2322 - accuracy: 0.2857
# Epoch 363/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0129 - accuracy: 0.3333
# Epoch 364/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0974 - accuracy: 0.3333
# Epoch 365/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2917 - accuracy: 0.3333
# Epoch 366/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3479 - accuracy: 0.1905
# Epoch 367/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2001 - accuracy: 0.3095
# Epoch 368/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2254 - accuracy: 0.3095
# Epoch 369/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0088 - accuracy: 0.2619
# Epoch 370/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0365 - accuracy: 0.2619
# Epoch 371/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0417 - accuracy: 0.3333
# Epoch 372/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0132 - accuracy: 0.3333
# Epoch 373/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0298 - accuracy: 0.3333
# Epoch 374/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0687 - accuracy: 0.3333
# Epoch 375/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0912 - accuracy: 0.3095
# Epoch 376/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9315 - accuracy: 0.3333
# Epoch 377/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6621 - accuracy: 0.2619
# Epoch 378/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0880 - accuracy: 0.3095
# Epoch 379/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0333 - accuracy: 0.3333
# Epoch 380/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1721 - accuracy: 0.3095
# Epoch 381/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0678 - accuracy: 0.3333
# Epoch 382/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1225 - accuracy: 0.3333
# Epoch 383/500
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0928 - accuracy: 0.1429
# Epoch 384/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2743 - accuracy: 0.2619
# Epoch 385/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0715 - accuracy: 0.3333
# Epoch 386/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1005 - accuracy: 0.3095
# Epoch 387/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.3333
# Epoch 388/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1243 - accuracy: 0.3333
# Epoch 389/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1312 - accuracy: 0.3095
# Epoch 390/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5699 - accuracy: 0.3095
# Epoch 391/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1176 - accuracy: 0.2857
# Epoch 392/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0392 - accuracy: 0.3333
# Epoch 393/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.3333
# Epoch 394/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0175 - accuracy: 0.3333
# Epoch 395/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2295 - accuracy: 0.3095
# Epoch 396/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0916 - accuracy: 0.2857
# Epoch 397/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5094 - accuracy: 0.2381
# Epoch 398/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0773 - accuracy: 0.3333
# Epoch 399/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1732 - accuracy: 0.3333
# Epoch 400/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0306 - accuracy: 0.3333
# Epoch 401/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2511 - accuracy: 0.2857
# Epoch 402/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0467 - accuracy: 0.3333
# Epoch 403/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1810 - accuracy: 0.3333
# Epoch 404/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3454 - accuracy: 0.3095
# Epoch 405/500
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1406 - accuracy: 0.1190
# Epoch 406/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0319 - accuracy: 0.3333
# Epoch 407/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0236 - accuracy: 0.3333
# Epoch 408/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0295 - accuracy: 0.3333
# Epoch 409/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1971 - accuracy: 0.3095
# Epoch 410/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.3333
# Epoch 411/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0897 - accuracy: 0.3333
# Epoch 412/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0214 - accuracy: 0.3333
# Epoch 413/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4928 - accuracy: 0.2619
# Epoch 414/500
# 5/5 [==============================] - 0s 11ms/step - loss: 2.3314 - accuracy: 0.2381
# Epoch 415/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0755 - accuracy: 0.3333
# Epoch 416/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0315 - accuracy: 0.3333
# Epoch 417/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0248 - accuracy: 0.3333
# Epoch 418/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 0.3333
# Epoch 419/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0918 - accuracy: 0.3333
# Epoch 420/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1465 - accuracy: 0.3333
# Epoch 421/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1298 - accuracy: 0.3095
# Epoch 422/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1283 - accuracy: 0.3095
# Epoch 423/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1843 - accuracy: 0.3333
# Epoch 424/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0643 - accuracy: 0.3333
# Epoch 425/500
# 5/5 [==============================] - 0s 10ms/step - loss: 1.9318 - accuracy: 0.2619
# Epoch 426/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.3959 - accuracy: 0.1667
# Epoch 427/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0505 - accuracy: 0.3333
# Epoch 428/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0231 - accuracy: 0.3333
# Epoch 429/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0236 - accuracy: 0.3333
# Epoch 430/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0158 - accuracy: 0.3333
# Epoch 431/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0408 - accuracy: 0.3333
# Epoch 432/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8639 - accuracy: 0.3333
# Epoch 433/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2757 - accuracy: 0.2857
# Epoch 434/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1233 - accuracy: 0.3333
# Epoch 435/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0367 - accuracy: 0.3333
# Epoch 436/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0319 - accuracy: 0.3333
# Epoch 437/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1165 - accuracy: 0.3333
# Epoch 438/500
# 5/5 [==============================] - 0s 9ms/step - loss: 1.3093 - accuracy: 0.2381
# Epoch 439/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6451 - accuracy: 0.2857
# Epoch 440/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0362 - accuracy: 0.3333
# Epoch 441/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0491 - accuracy: 0.3333
# Epoch 442/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2497 - accuracy: 0.3333
# Epoch 443/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0191 - accuracy: 0.3333
# Epoch 444/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3923 - accuracy: 0.2619
# Epoch 445/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0791 - accuracy: 0.3095
# Epoch 446/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0422 - accuracy: 0.3333
# Epoch 447/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0633 - accuracy: 0.3333
# Epoch 448/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9829 - accuracy: 0.2857
# Epoch 449/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2460 - accuracy: 0.3095
# Epoch 450/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.3333
# Epoch 451/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0322 - accuracy: 0.3333
# Epoch 452/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0476 - accuracy: 0.3333
# Epoch 453/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3925 - accuracy: 0.2857
# Epoch 454/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0293 - accuracy: 0.3333
# Epoch 455/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1156 - accuracy: 0.3095
# Epoch 456/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7087 - accuracy: 0.2857
# Epoch 457/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3393 - accuracy: 0.3333
# Epoch 458/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0213 - accuracy: 0.3333
# Epoch 459/500
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0098 - accuracy: 0.3333
# Epoch 460/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0271 - accuracy: 0.3333
# Epoch 461/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6149 - accuracy: 0.3095
# Epoch 462/500
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5361 - accuracy: 0.0952
# Epoch 463/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0460 - accuracy: 0.3333
# Epoch 464/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 0.3333
# Epoch 465/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0142 - accuracy: 0.3333
# Epoch 466/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0134 - accuracy: 0.3333
# Epoch 467/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0978 - accuracy: 0.3095
# Epoch 468/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.3333
# Epoch 469/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3170 - accuracy: 0.3095
# Epoch 470/500
# 5/5 [==============================] - 0s 8ms/step - loss: 1.3626 - accuracy: 0.2143
# Epoch 471/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3547 - accuracy: 0.3333
# Epoch 472/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0282 - accuracy: 0.3333
# Epoch 473/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0296 - accuracy: 0.3333
# Epoch 474/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0454 - accuracy: 0.3333
# Epoch 475/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0185 - accuracy: 0.3333
# Epoch 476/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4885 - accuracy: 0.3095
# Epoch 477/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1056 - accuracy: 0.2857
# Epoch 478/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0544 - accuracy: 0.3333
# Epoch 479/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1011 - accuracy: 0.3333
# Epoch 480/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0511 - accuracy: 0.3333
# Epoch 481/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9754 - accuracy: 0.2619
# Epoch 482/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2578 - accuracy: 0.2857
# Epoch 483/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0220 - accuracy: 0.3333
# Epoch 484/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0940 - accuracy: 0.3333
# Epoch 485/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0415 - accuracy: 0.3333
# Epoch 486/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1596 - accuracy: 0.3095
# Epoch 487/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1082 - accuracy: 0.3333
# Epoch 488/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1480 - accuracy: 0.3095
# Epoch 489/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3020 - accuracy: 0.3095
# Epoch 490/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5932 - accuracy: 0.2619
# Epoch 491/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3565 - accuracy: 0.2857
# Epoch 492/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0312 - accuracy: 0.3333
# Epoch 493/500
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0179 - accuracy: 0.3333
# Epoch 494/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0545 - accuracy: 0.3333
# Epoch 495/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1614 - accuracy: 0.3333
# Epoch 496/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0416 - accuracy: 0.3095
# Epoch 497/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4189 - accuracy: 0.2857
# Epoch 498/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7334 - accuracy: 0.3095
# Epoch 499/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1187 - accuracy: 0.3333
# Epoch 500/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0312 - accuracy: 0.3333

# %%
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 
        idclPred = predClass[i][0]

        ## determina clase predecida de acuerdo al umbral de clasificación
        idclPredRnd = int(idclPred)
        if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

        # muestra comparación con la imagen
        fig = plt.figure()
        fig.suptitle( strTitulo )
        ax1 = fig.add_subplot(121)
        plot_image( x[i] )
        
        plt.tight_layout()
        fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       1.00      1.00      1.00         7
#      insecto       1.00      1.00      1.00         7
# invertebrado       1.00      1.00      1.00         7
#     mamifero       1.00      1.00      1.00         7
#          pez       1.00      1.00      1.00         7
#       reptil       1.00      1.00      1.00         7
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42
#
#
# Matriz de Confusión:
#                 p:pez  p:mamifero  p:ave  p:invertebrado  p:insecto  p:reptil
# r:pez               7           0      0               0          0         0
# r:mamifero          0           7      0               0          0         0
# r:ave               0           0      7               0          0         0
# r:invertebrado      0           0      0               7          0         0
# r:insecto           0           0      0               0          7         0
# r:reptil            0           0      0               0          0         7
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, y_test)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Entrenamiento: ")
probarModelo(x_test, y_test, clases_map)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6696 - accuracy: 0.1667
#
# >Evaluación del Modelo:
#     - Error:  4.669580459594727
#     - Exactitud:  16.66666716337204
#
#
#
#
# *** Resultados con datos de Entrenamiento:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       0.25      0.33      0.29         3
#      insecto       0.00      0.00      0.00         3
# invertebrado       0.25      0.33      0.29         3
#     mamifero       0.00      0.00      0.00         3
#          pez       0.00      0.00      0.00         3
#       reptil       0.00      0.00      0.00         3
#
#     accuracy                           0.11        18
#    macro avg       0.08      0.11      0.10        18
# weighted avg       0.08      0.11      0.10        18
#
#
# Matriz de Confusión:
#                 p:pez  p:mamifero  p:ave  p:invertebrado  p:insecto  p:reptil
# r:pez               0           2      1               0          0         0
# r:mamifero          0           0      1               2          0         0
# r:ave               0           0      1               1          0         1
# r:invertebrado      0           0      0               1          0         2
# r:insecto           1           1      1               0          0         0
# r:reptil            1           0      0               0          2         0
#
#
#
# >Resultados:
