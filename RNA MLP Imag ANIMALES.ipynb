# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation para procesar las imágenes de ANIMALES e identificar el tipo correspondiente

# %% [markdown]
# 1) Cargar librerías:

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import plot_model

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Using TensorFlow backend.
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
# tamaño de las imágenes
IMAGE_SHAPE = (32, 32, 1)

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# define tamaño de datos de salida (las clases están codificadas en un único número)
num_outputs = 1 

# cantidad de neuronas ocultas 
hidden_layers = [ 784, 392, 56, 32 ] 

# cantidad de épocas del entrenamiento
cantEpocas = 100

print("Configuración de RNA MLP Backpropagation definida: [", num_inputs, hidden_layers, num_outputs," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida: [ 1024 [784, 392, 56, 32] 1  ]

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo ANIMALES' 
imagPath = path + '/imagenes/train'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
# cargar las imágenes
classes_ori = [] 
images_ori = []

all_dirs = os.listdir( imagPath )
for each_dir in all_dirs:

    auxiPath = imagPath + '/' + each_dir 
    imagFN  = os.listdir( auxiPath )
    for each_imagFN in imagFN:
          
          # abre la imagen
          imag = Image.open(auxiPath + "/" + each_imagFN)
          
          # ajusta el tamaño
          if IMAGE_SHAPE[2]==1:
            imag = imag.convert('L')
            tipoImage = 'L'
          else:
            tipoImage = 'RGB'
          imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
          
          # transforma a un vector de nros
          arImag = np.array(imag)
          
          # agrega a los vectores
          classes_ori.append( each_dir )
          images_ori.append( arImag )

print("- Clases cargadas: ", len(classes_ori))
print("- Imágenes cargadas: ", len(images_ori))

if len(images_ori)>0:
  print("\n- Ejemplo ", classes_ori[0], " ", images_ori[0].shape, ": ")
  display( Image.fromarray(images_ori[0], tipoImage) )
# Out:
# - Clases cargadas:  42
# - Imágenes cargadas:  42
#
# - Ejemplo  invertebrado   (32, 32) :
# <PIL.Image.Image image mode=L size=32x32 at 0x7F4C504DF828>

# %%
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return auxiAr

# define vector auxiliar de datos de entrada para usar en el entrenamiento
x_train = prepare_imageList(images_ori)

# define vector auxiliar de datos de salida para usar en el entrenamiento
# también usa esta información para determinar la cantida de neuronas de salida
SPECIES = list(set(classes_ori))
SPECIES_dict = dict( zip( SPECIES, range(len(SPECIES)) ) )
y_train = []
for cl in classes_ori:
    y_train.append( SPECIES_dict[cl] )


print("x_train (cant ejemplos, datos entrada): ", x_train.shape)
print("y_train (cant): ", len(y_train))
print("\nImagen reconstruida de ", classes_ori[0], "(", y_train[0], ")")
plot_image(x_train[0])
# Out:
# x_train (cant ejemplos, datos entrada):  (42, 1024)
# y_train (cant):  42
#
# Imagen reconstruida de  invertebrado ( 4 )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for num_hid in hidden_layers:  
    
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(num_hid, name=auxlayerName)(eachLay) # capas ocultas


output_img_Lay = Dense(num_outputs, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  6  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       (None, 1024)              0
# _________________________________________________________________
# hidd_1 (Dense)               (None, 784)               803600
# _________________________________________________________________
# hidd_2 (Dense)               (None, 392)               307720
# _________________________________________________________________
# hidd_3 (Dense)               (None, 56)                22008
# _________________________________________________________________
# hidd_4 (Dense)               (None, 32)                1824
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 1,135,185
# Trainable params: 1,135,185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
# lleva a cabo el entrenamiento
model.fit(x_train, y_train,
                epochs = cantEpocas, 
                batch_size = 5)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 0s 8ms/step - loss: 541.8262 - accuracy: 0.1429
# Epoch 2/100
# 42/42 [==============================] - 0s 2ms/step - loss: 6.4358 - accuracy: 0.2381
# Epoch 3/100
# 42/42 [==============================] - 0s 2ms/step - loss: 6.7696 - accuracy: 0.1667
# Epoch 4/100
# 42/42 [==============================] - 0s 2ms/step - loss: 10.2810 - accuracy: 0.1190
# Epoch 5/100
# 42/42 [==============================] - 0s 2ms/step - loss: 8.2050 - accuracy: 0.1190
# Epoch 6/100
# 42/42 [==============================] - 0s 2ms/step - loss: 9.3823 - accuracy: 0.1667
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.8606 - accuracy: 0.3333
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 5.3387 - accuracy: 0.1667
# Epoch 9/100
# 42/42 [==============================] - 0s 2ms/step - loss: 2.1315 - accuracy: 0.2143
# Epoch 10/100
# 42/42 [==============================] - 0s 2ms/step - loss: 2.3775 - accuracy: 0.2619
# Epoch 11/100
# 42/42 [==============================] - 0s 2ms/step - loss: 6.8808 - accuracy: 0.1667
# Epoch 12/100
# 42/42 [==============================] - 0s 2ms/step - loss: 3.4527 - accuracy: 0.1667
# Epoch 13/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1815 - accuracy: 0.4762
# Epoch 14/100
# 42/42 [==============================] - 0s 2ms/step - loss: 17.0953 - accuracy: 0.2619
# Epoch 15/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.5400 - accuracy: 0.2381
# Epoch 16/100
# 42/42 [==============================] - 0s 2ms/step - loss: 3.3969 - accuracy: 0.2143
# Epoch 17/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.9998 - accuracy: 0.3810
# Epoch 18/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.5578 - accuracy: 0.2857
# Epoch 19/100
# 42/42 [==============================] - 0s 2ms/step - loss: 2.0413 - accuracy: 0.2857
# Epoch 20/100
# 42/42 [==============================] - 0s 2ms/step - loss: 2.8938 - accuracy: 0.2857
# Epoch 21/100
# 42/42 [==============================] - 0s 2ms/step - loss: 4.5052 - accuracy: 0.1905
# Epoch 22/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1110 - accuracy: 0.3333
# Epoch 23/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8435 - accuracy: 0.3333
# Epoch 24/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4063 - accuracy: 0.4286
# Epoch 25/100
# 42/42 [==============================] - 0s 2ms/step - loss: 7.2807 - accuracy: 0.2143
# Epoch 26/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.0639 - accuracy: 0.4048
# Epoch 27/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.3572 - accuracy: 0.4286
# Epoch 28/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1289 - accuracy: 0.3571
# Epoch 29/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1616 - accuracy: 0.4286
# Epoch 30/100
# 42/42 [==============================] - 0s 2ms/step - loss: 4.0694 - accuracy: 0.1190
# Epoch 31/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1896 - accuracy: 0.4048
# Epoch 32/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4618 - accuracy: 0.3333
# Epoch 33/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1507 - accuracy: 0.4048
# Epoch 34/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.5714
# Epoch 35/100
# 42/42 [==============================] - 0s 2ms/step - loss: 7.4428 - accuracy: 0.2619
# Epoch 36/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.5808 - accuracy: 0.4048
# Epoch 37/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6743 - accuracy: 0.5238
# Epoch 38/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9139 - accuracy: 0.3571
# Epoch 39/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7883 - accuracy: 0.4048
# Epoch 40/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.5714
# Epoch 41/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.3772 - accuracy: 0.3571
# Epoch 42/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.0466 - accuracy: 0.4524
# Epoch 43/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.0470 - accuracy: 0.4524
# Epoch 44/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.8014 - accuracy: 0.2381
# Epoch 45/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.4286
# Epoch 46/100
# 42/42 [==============================] - 0s 2ms/step - loss: 4.6558 - accuracy: 0.1667
# Epoch 47/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.6667
# Epoch 48/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2942 - accuracy: 0.5952
# Epoch 49/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.4185 - accuracy: 0.4048
# Epoch 50/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4001 - accuracy: 0.3095
# Epoch 51/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4537 - accuracy: 0.5476
# Epoch 52/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9699 - accuracy: 0.4762
# Epoch 53/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.3739 - accuracy: 0.3810
# Epoch 54/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6642 - accuracy: 0.5714
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7751 - accuracy: 0.4762
# Epoch 56/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.3840 - accuracy: 0.3810
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6069 - accuracy: 0.4048
# Epoch 58/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4726 - accuracy: 0.2143
# Epoch 59/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.4524
# Epoch 60/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7308 - accuracy: 0.3571
# Epoch 61/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2585 - accuracy: 0.3810
# Epoch 62/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6199 - accuracy: 0.4524
# Epoch 63/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.9226 - accuracy: 0.2857
# Epoch 64/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.6190
# Epoch 65/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7158 - accuracy: 0.3571
# Epoch 66/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.7857
# Epoch 67/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.9386 - accuracy: 0.4286
# Epoch 68/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8750 - accuracy: 0.4048
# Epoch 69/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.6905
# Epoch 70/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6719 - accuracy: 0.6667
# Epoch 71/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 72/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.5714
# Epoch 73/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7911 - accuracy: 0.4286
# Epoch 74/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7615 - accuracy: 0.4048
# Epoch 75/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.6190
# Epoch 76/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.7462 - accuracy: 0.2381
# Epoch 77/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7748 - accuracy: 0.5000
# Epoch 78/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9524
# Epoch 79/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.5714
# Epoch 80/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2681 - accuracy: 0.2857
# Epoch 81/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.7143
# Epoch 82/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.7619
# Epoch 83/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9186 - accuracy: 0.3095
# Epoch 84/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.6667
# Epoch 85/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.4944 - accuracy: 0.3095
# Epoch 86/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1622 - accuracy: 0.7857
# Epoch 87/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.6667
# Epoch 88/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.7619
# Epoch 89/100
# 42/42 [==============================] - 0s 2ms/step - loss: 3.9721 - accuracy: 0.3095
# Epoch 90/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.6429
# Epoch 91/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9286
# Epoch 92/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.7381
# Epoch 93/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.7882 - accuracy: 0.3333
# Epoch 94/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9524
# Epoch 95/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1496 - accuracy: 0.3333
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6231 - accuracy: 0.3571
# Epoch 97/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.7381
# Epoch 98/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3326 - accuracy: 0.5714
# Epoch 99/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.7289 - accuracy: 0.2143
# Epoch 100/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.6905

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado:
#    (notar que utiliza las mismas imágenes que se usaron para el entrenamiento!)

# %%
 # evalua al modelo entrenado
resEval = model.evaluate(x_train, y_train)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")
# Out:
# 42/42 [==============================] - 0s 581us/step
#
# >Evaluación del Modelo:
#     - Error:  0.042370170975724854
#     - Exactitud:  100.0

# %%
# procesa las imágenes con el modelo 
predClass = model.predict(x_train)

# muestra los resultados con las imágenes 
umbralClas = 0.5
classPreds = []
classReal = []
for i in range(len(x_train)):

    # prepara salida
    clReal = classes_ori[i]
    idclPred = predClass[i][0]

    ## determina clase predecida de acuerdo al umbral de clasificación
    idclPredRnd = int(idclPred)
    if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(SPECIES):
            idclPredRnd = idclPredRnd + 1

    if idclPredRnd<0 or idclPredRnd>=len(SPECIES):
        clPred = "INVÁLIDA!"
    else:      
        clPred = SPECIES[ idclPredRnd ]

    classReal.append( clReal )
    classPreds.append( clPred )

    strTitulo = 'Real: ' + clReal + ' / RNA: ' 
    strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

    # muestra comparación con la imagen
    fig = plt.figure()
    fig.suptitle( strTitulo )
    ax1 = fig.add_subplot(121)
    plot_image(x_train[i])
    
    plt.tight_layout()
    fig = plt.gcf()

# muestra reporte de clasificación
print("\n Reporte de Clasificación: ")
print(classification_report(classReal, classPreds))

# muestra matriz de confusion
print('\nMatriz de Confusión: ')
cm = confusion_matrix(classReal, classPreds, labels=SPECIES)
cmtx = pd.DataFrame(
    cm, 
    index=['r:{:}'.format(x) for x in SPECIES], 
    columns=['p:{:}'.format(x) for x in SPECIES]
  )
print(cmtx)
print("\n")

print("\n>Resultados: ")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       1.00      1.00      1.00         7
#      insecto       1.00      1.00      1.00         7
# invertebrado       1.00      1.00      1.00         7
#     mamifero       1.00      1.00      1.00         7
#          pez       1.00      1.00      1.00         7
#       reptil       1.00      1.00      1.00         7
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42
#
#
# Matriz de Confusión:
#                 p:insecto  p:ave  p:reptil  p:pez  p:invertebrado  p:mamifero
# r:insecto               7      0         0      0               0           0
# r:ave                   0      7         0      0               0           0
# r:reptil                0      0         7      0               0           0
# r:pez                   0      0         0      7               0           0
# r:invertebrado          0      0         0      0               7           0
# r:mamifero              0      0         0      0               0           7
#
#
#
# >Resultados:
