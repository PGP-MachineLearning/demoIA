# %% [markdown]
# # Demo de implementación de un Algoritmo Genético (AG) para resolver el problema de encontrar un Máximo Óptimo definido al azar en un plano y tratando de esquivar los máximos locales aleatorios
# Utiliza la librería DEAP disponible en https://deap.readthedocs.io/en/master/

# %% [markdown]
# 0) Preparar el ambiente:

# %%
#@title
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.19.5)

# %% [markdown]
# 1) Importar librerías:

# %%
#@title
import random
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML
from deap import base
from deap import creator
from deap import tools

import pickle
import codecs

print("\nLibrerías importadas")
# Out:
# Librerías importadas

# %% [markdown]
# 2) Establecer parámetros generales de la Corrida:

# %%
# Espacio  de búsqueda
CANT_MAXIMOS_LOCALES = 3 #@param {type:"slider", min:0, max:10, step:1}
MIN_ESPACIO_BUSQ = -1000 #@param {type:"slider", min:-1000, max:0, step:10}
MAX_ESPACIO_BUSQ = 1000  #@param {type:"slider", min:0, max:1000, step:10}

# Cantidad de Ciclos de la Corrida
CANT_CICLOS = 250 #@param {type:"integer"}

# Cantidad de Individuos en la Población
CANT_INDIVIDUOS_POBLACION = 15  #@param {type:"slider", min:1, max:100, step:1}

# Probabilidad del Mutación 
PROBAB_MUTACION = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}

# Indica si se muestra el detalle de las estadísticas en cada ciclo
MUESTRA_ESTADISTICAS = True #@param {type:"boolean"}

print("\nParámetros de la Corrida definidos")
# Out:
# Parámetros de la Corrida definidos

# %% [markdown]
# 2) Inicializar objetos de DEAP para utilizar e indicar Operadores Genéticos:

# %%
## Inicializa objeto Toolbox auxiliar
toolbox = base.Toolbox()

## OPERADORES GENÉTICOS
## (ver lista completa en https://deap.readthedocs.io/en/master/api/tools.html#operators )


tipo_seleccion = 'Azar' #@param ["Azar", "Torneo", "Ranking", "Ruleta", "Control s/Número Esperado"]
tipo_cruzamiento = 'Simple-1Punto' #@param ["Simple-1Punto", "Simple-2Puntos", "Azar"]

# Registrar tipo de Selección a aplicar con sus parámetros
if tipo_seleccion == 'Torneo':
  toolbox.register("select", tools.selTournament, tournsize=2)
elif tipo_seleccion == 'Ranking':
  toolbox.register("select", tools.selBest)
elif tipo_seleccion == 'Ruleta':
  toolbox.register("select", tools.selRoulette)
elif tipo_seleccion == 'Control s/Número Esperado':
  toolbox.register("select", tools.selStochasticUniversalSampling)
else:
  toolbox.register("select", tools.selRandom)

# Registrar tipo de Cruzamiento a aplicar con sus parámetros
if tipo_cruzamiento == 'Simple-1Punto':
  toolbox.register("mate", tools.cxOnePoint)
elif tipo_cruzamiento == 'Simple-2Puntos':
  toolbox.register("mate",  tools.cxTwoPoint)  
else:
  toolbox.register("mate", tools.cxUniform, indpb=0.5)

# Registrar tipo de Mutación a aplicar con sus parámetros
toolbox.register("mutate", tools.mutUniformInt, low=MIN_ESPACIO_BUSQ, up=MAX_ESPACIO_BUSQ, indpb=0.2)

print("\nOperadores Genéticos definidos")
# Out:
# Operadores Genéticos definidos

# %% [markdown]
# 3) Especificar Estructura del Cromosoma y Función de Aptitud:

# %%
#@title clase MAPA DE BÚSQUEDA
Hash_configuracion_Mapa_Busqueda = "gANjX19tYWluX18KTWFwYUJ1c3F1ZWRhCnEAKYFxAX1xAihYBgAAAGxpbU1pbnEDShj8//9YBgAA AGxpbU1heHEETegDWAcAAABjYW50TWF4cQVLA1gKAAAATWF4aW1vc1Bvc3EGXXEHKF1xCChN3gFK kP///2VdcQkoTRkDSoH///9lXXEKKE0gA0oW/f//ZV1xCyhLhk0KAmVlWAoAAABNYXhpbW9zVmFs cQxdcQ0oS2BLYkshSx1lWAsAAABNYXhPcHRpbW9JRHEOSwF1Yi4=" #@param {type:"string"}

class MapaBusqueda(object):

    def __init__(self, limMin, limMax, cantMaximosLocales=0):
          self.limMin = limMin
          self.limMax = limMax
          self.cantMax = cantMaximosLocales
          self.generarPosicionesRnd()

    def generarPosicionesRnd(self):
      
        # Define Posiciones Random para Máximos Locales y Óptimos
        # con Heurística también al Azar (entre 1 y 100)
        # controla que el máximo local/global no se ubique en la misma posición que el Hormiguero
        self.MaximosPos = []
        self.MaximosVal = []
        self.MaxOptimoID = 0
        auxMejorVal = -99
        i = 0
        while len(self.MaximosPos)<(self.cantMax+1):

            auxPos = [ random.randint(self.limMin, self.limMax),  random.randint(self.limMin, self.limMax) ]        
            auxVal = random.randint(-20, 100)

            self.MaximosPos.append( auxPos )
            self.MaximosVal.append( auxVal )
            
            if self.MaximosVal[self.MaxOptimoID] < auxVal:
                self.MaxOptimoID = i
            i= i + 1

        return True
   
    def printInformacion(self):
        # Muestra la información sobre el Mapa de Búsqueda
        print("\n** Máximos Generados: ", len(self.MaximosPos))
        for auxPos, auxVal in zip(self.MaximosPos, self.MaximosVal):
            print("  -->", auxPos, "{ ", auxVal, " } ")
        print("\n** Posición Máximo Óptimo: ", self.MaximosPos[self.MaxOptimoID], " { ",  self.MaximosVal[self.MaxOptimoID]," } **")
        print("\n")

    @property
    def posMaximos(self):
        return self.MaximosPos    

    @property
    def valMaximos(self):
        return self.MaximosVal   
        
    @property
    def posMaximoGlobal(self):
        return self.MaximosPos[self.MaxOptimoID]         
    
    @property
    def valMaximoGlobal(self):
        return self.MaximosVal[self.MaxOptimoID]  

    def estaEnMaximo(self, posicion):
      # Indica si la posición corresponde o no a un Máximo 
      # si es verdadero devuelve el valor correspondiente, sino 0
      for i in range(len(self.MaximosPos)):
        if posicion==self.MaximosPos[i]:
          return self.MaximosVal[i]
      return 0

    def funcHeuristica(self, posicion):
        # Define la Función Heurística para evaluar una posicion del mapa
        devuelve = 0
        disPosMenor = self.limMax
        for posMax, valMax in zip(self.MaximosPos, self.MaximosVal):

              # calcula la distancia al punto de la Particula
              sqerrors = ((x - y)**2 for x, y in zip(posicion, posMax))
              distPos =  math.fsum(sqerrors)**0.5 / 10
              
              # Si es la menor distancia calcula la Heurística
              if disPosMenor > distPos:
                  disPosMenor = distPos 
                  devuelve = ( valMax - distPos) 

          # Por las dudas controla que devuelva un valor positivo
        return max(devuelve,0)


print("\nClase Mapa de Búqueda definida") 

# si tiene la configuración definida, la carga sino crea nueva clase
if Hash_configuracion_Mapa_Busqueda != "":
  print("\n> Usando configuración de mapa de búsqueda definida en hash.")
  mapa = pickle.loads(codecs.decode(Hash_configuracion_Mapa_Busqueda.encode(), "base64"))
else:
  # sino define el Mapa de Búsqueda nuevo
  print("\n> Creando nuevo mapa de búsqueda.")
  mapa = MapaBusqueda(limMin=MIN_ESPACIO_BUSQ, limMax=MAX_ESPACIO_BUSQ, \
                      cantMaximosLocales=CANT_MAXIMOS_LOCALES)

print("\n> Mapa de búsqueda definido:")
mapa.printInformacion()

print("\n> Hash del mapa de búsqueda definido: ")
print( codecs.encode(pickle.dumps(mapa), "base64").decode() )
# Out:
# Clase Mapa de Búqueda definida
#
# > Usando configuración de mapa de búsqueda definida en hash.
#
# > Mapa de búsqueda definido:
#
# ** Máximos Generados:  4
#   --> [478, -112] {  96  }
#   --> [793, -127] {  98  }
#   --> [800, -746] {  33  }
#   --> [134, 522] {  29  }
#
# ** Posición Máximo Óptimo:  [793, -127]  {  98  } **
#
#
#
# > Hash del mapa de búsqueda definido:
# gANjX19tYWluX18KTWFwYUJ1c3F1ZWRhCnEAKYFxAX1xAihYBgAAAGxpbU1pbnEDShj8//9YBgAA
# AGxpbU1heHEETegDWAcAAABjYW50TWF4cQVLA1gKAAAATWF4aW1vc1Bvc3EGXXEHKF1xCChN3gFK
# kP///2VdcQkoTRkDSoH///9lXXEKKE0gA0oW/f//ZV1xCyhLhk0KAmVlWAoAAABNYXhpbW9zVmFs
# cQxdcQ0oS2BLYkshSx1lWAsAAABNYXhPcHRpbW9JRHEOSwF1Yi4=

# %%
#@title FUNCIÓN DE APTITUD Y ESTRUCTURA DEL CROMOSOMA

# indica que es la función de aptitud es para maximizar
creator.create("Fitness", base.Fitness, weights=(1.0,))

# definimos la función de aptitud a evaluar
def funcAptitud(individuo):

    return mapa.funcHeuristica(individuo),
    
# registra la función que se va a evaluar
toolbox.register("evaluate", funcAptitud)

print("\nFunción de Aptitud definida")

# indica que los individuos son una lista de genes que aplica la función antes definida
creator.create("Individual", list, fitness=creator.Fitness)

# indica que los genes son float correspondiente a las posiciones
toolbox.register("attr_int", random.randint, MIN_ESPACIO_BUSQ, MAX_ESPACIO_BUSQ) 

# registra el tipo de individuo y población a usar
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_int, 2)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

print("\nCromosoma definido")
# Out:
# Función de Aptitud definida
#
# Cromosoma definido

# %% [markdown]
# 4) Ejecutar la corrida del algoritmo mostrando resultados:

# %%
#@title EJECUCIÓN DE LA CORRIDA


## Define una función auxiliar para calcular estadísticas y guarda info en vectores auxiliares
def CalculoEstadisticas(ciclo, indivPobla, muestra, mejorMax = True):
    
    global mejorIndCorrida, mejorIndCorrida_ciclo
    global ciclosMaxAptitud
    global ciclosPromAptitud
    global ciclosMinAptitud

    if len(indivPobla) == 0:
      return None, 0, 0, 0 

    auxMax = None
    auxMin = None
    auxSum = 0
    auxBestInd = None
    auxBestIndApt = None
    
    for ind in indivPobla:

        apt = round(ind.fitness.values[0], 2)
        auxSum = auxSum + apt

        if (auxMax == None) or (apt > auxMax):
            auxMax = apt
            if mejorMax:
              auxBestInd = ind
              auxBestIndApt = apt

        if (auxMin == None) or (apt < auxMin):
            auxMin = apt
            if not mejorMax:
              auxBestInd = ind
              auxBestIndApt = apt

    auxProm = round(auxSum / len(indivPobla),2)

    if (mejorIndCorrida == None) or (mejorIndCorrida.fitness.values < auxBestInd.fitness.values):
          mejorIndCorrida = auxBestInd
          mejorIndCorrida_ciclo = ciclo
    ciclosMaxAptitud.append( auxMax )
    ciclosPromAptitud.append( auxProm )
    ciclosMinAptitud.append( auxMin )

    if muestra:          
        print("\n-- Ciclo  %i --" % ciclo)
        print(" Mejor Individuo:", auxBestInd, " {", auxBestIndApt, "}")
        print("   Max: ", auxMax, " / Promedio: ", auxProm, " / Min: ", auxMin)

    return auxBestInd, auxMax, auxProm, auxMin


# Muestra su información
mapa.printInformacion()

# Determina mínima Heuristica para finalizar el algoritmo
MIN_HEURISTICA_FINALIZAR = mapa.valMaximoGlobal - 1
print("-- Mínima heurística para finalizar la Corrida: ", MIN_HEURISTICA_FINALIZAR, "--")

# vectores auxiliares 
ciclo = 1    
mejorIndCorrida = None
mejorIndCorrida_ciclo = 0
ciclosIndiv = []
ciclosMaxAptitud = []
ciclosPromAptitud = []
ciclosMinAptitud = []

# Define la población inicial
indivPobla = toolbox.population(n=CANT_INDIVIDUOS_POBLACION)

# Asigna el valor de aptitud a los individuos de la población inicial
fitnesses = list(map(toolbox.evaluate, indivPobla))
for ind, fit in zip(indivPobla, fitnesses):
    ind.fitness.values = fit

ciclosIndiv.append( [] )
ciclosIndiv[0].extend( indivPobla )

# Cálcula estadísticas y guarda info en vectores auxiliares
auxBestInd, auxMax, auxProm, auxMin = CalculoEstadisticas(0, indivPobla, MUESTRA_ESTADISTICAS)

# Finaliza cuando llegue a la cantidad de ciclos 
#     o cuando la heurística del mejor sea mayor a un mínimo
while (ciclo < CANT_CICLOS) \
        and ((mejorIndCorrida==None) or (mejorIndCorrida.fitness.values[0]<MIN_HEURISTICA_FINALIZAR)):

    # Realiza la Selección
    indivSelecc = toolbox.select(indivPobla, len(indivPobla))

    # Inicializa a los hijos clonando a los seleccionados
    indivHijos = list(map(toolbox.clone, indivSelecc))
    
    # Realiza el Cruzamiento
    for hijo1, hijo2 in zip(indivHijos[::2], indivHijos[1::2]):
            toolbox.mate(hijo1, hijo2)
            del hijo1.fitness.values
            del hijo2.fitness.values

    # Realiza la Mutación
    for mutant in indivHijos:
        if random.random() < PROBAB_MUTACION:
            toolbox.mutate(mutant)
            del mutant.fitness.values
            break # solo muta 1 vez por vuelta
              
    # Evalua a los individuos que salen de la Mutación
    #  para determinar si son válidos y su valor de aptitud
    invalid_ind = [ind for ind in indivHijos if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit
    
    # Reemplaza la población actual con los hijos
    indivPobla[:] = indivHijos
    ciclosIndiv.append( [] )
    ciclosIndiv[ciclo].extend( indivPobla )
    
    # Cálcula estadísticas y guarda info en vectores auxiliares
    auxBestInd, auxMax, auxProm, auxMin = CalculoEstadisticas(ciclo, indivPobla, MUESTRA_ESTADISTICAS)

    ciclo = ciclo + 1

print("\n-- Corrida Finalizada en %i ciclos --\n" % ciclo )

print("** Posición Máximo Óptimo a Buscar: ", mapa.posMaximoGlobal, " { ",  mapa.valMaximoGlobal," } **")
print("== Mejor Individuo de la Corrida:", mejorIndCorrida, " { ", round(mejorIndCorrida.fitness.values[0], 3), " }  ==")
# Out:
# ** Máximos Generados:  4
#   --> [478, -112] {  96  }
#   --> [793, -127] {  98  }
#   --> [800, -746] {  33  }
#   --> [134, 522] {  29  }
#
# ** Posición Máximo Óptimo:  [793, -127]  {  98  } **
#
#
# -- Mínima heurística para finalizar la Corrida:  97 --
#
# -- Ciclo  0 --
#  Mejor Individuo: [750, -138]  { 93.56 }
#    Max:  93.56  / Promedio:  17.39  / Min:  0.0
#
# -- Ciclo  1 --
#  Mejor Individuo: [602, 210]  { 61.49 }
#    Max:  61.49  / Promedio:  16.22  / Min:  0.0
#
# -- Ciclo  2 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  17.22  / Min:  0.0
#
# -- Ciclo  3 --
#  Mejor Individuo: [670, -138]  { 85.65 }
#    Max:  85.65  / Promedio:  30.59  / Min:  0.0
#
# -- Ciclo  4 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  33.22  / Min:  0.0
#
# -- Ciclo  5 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  42.31  / Min:  0.0
#
# -- Ciclo  6 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  34.6  / Min:  0.0
#
# -- Ciclo  7 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  38.46  / Min:  0.0
#
# -- Ciclo  8 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  38.46  / Min:  0.0
#
# -- Ciclo  9 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  30.79  / Min:  0.0
#
# -- Ciclo  10 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  30.73  / Min:  0.0
#
# -- Ciclo  11 --
#  Mejor Individuo: [703, 258]  { 58.46 }
#    Max:  58.46  / Promedio:  34.66  / Min:  0.0
#
# -- Ciclo  12 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  26.97  / Min:  0.0
#
# -- Ciclo  13 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  34.67  / Min:  0.0
#
# -- Ciclo  14 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  30.81  / Min:  0.0
#
# -- Ciclo  15 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  34.7  / Min:  0.0
#
# -- Ciclo  16 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  30.89  / Min:  0.0
#
# -- Ciclo  17 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  15.41  / Min:  0.0
#
# -- Ciclo  18 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  11.54  / Min:  0.0
#
# -- Ciclo  19 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  7.73  / Min:  0.0
#
# -- Ciclo  20 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  11.59  / Min:  0.0
#
# -- Ciclo  21 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  13.06  / Min:  0.0
#
# -- Ciclo  22 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  9.2  / Min:  0.0
#
# -- Ciclo  23 --
#  Mejor Individuo: [670, 254]  { 57.96 }
#    Max:  57.96  / Promedio:  15.41  / Min:  0.0
#
# -- Ciclo  24 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  22.29  / Min:  0.0
#
# -- Ciclo  25 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  42.2  / Min:  0.0
#
# -- Ciclo  26 --
#  Mejor Individuo: [670, -352]  { 72.36 }
#    Max:  72.36  / Promedio:  21.21  / Min:  0.0
#
# -- Ciclo  27 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  22.89  / Min:  0.0
#
# -- Ciclo  28 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  24.63  / Min:  0.0
#
# -- Ciclo  29 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  33.27  / Min:  0.0
#
# -- Ciclo  30 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  47.61  / Min:  0.0
#
# -- Ciclo  31 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  51.45  / Min:  0.0
#
# -- Ciclo  32 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  53.06  / Min:  0.0
#
# -- Ciclo  33 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  54.48  / Min:  0.0
#
# -- Ciclo  34 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  56.32  / Min:  0.0
#
# -- Ciclo  35 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  63.77  / Min:  0.0
#
# -- Ciclo  36 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  55.66  / Min:  0.0
#
# -- Ciclo  37 --
#  Mejor Individuo: [670, -253]  { 80.39 }
#    Max:  80.39  / Promedio:  46.25  / Min:  0.0
#
# -- Ciclo  38 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  49.9  / Min:  0.0
#
# -- Ciclo  39 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  42.23  / Min:  0.0
#
# -- Ciclo  40 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  34.55  / Min:  0.0
#
# -- Ciclo  41 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  38.39  / Min:  0.0
#
# -- Ciclo  42 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  34.55  / Min:  0.0
#
# -- Ciclo  43 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  19.19  / Min:  0.0
#
# -- Ciclo  44 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  15.35  / Min:  0.0
#
# -- Ciclo  45 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  12.13  / Min:  0.0
#
# -- Ciclo  46 --
#  Mejor Individuo: [670, -216]  { 82.82 }
#    Max:  82.82  / Promedio:  13.2  / Min:  0.0
#
# -- Ciclo  47 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  3.84  / Min:  0.0
#
# -- Ciclo  48 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  7.68  / Min:  0.0
#
# -- Ciclo  49 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  15.35  / Min:  0.0
#
# -- Ciclo  50 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  7.68  / Min:  0.0
#
# -- Ciclo  51 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  3.84  / Min:  0.0
#
# -- Ciclo  52 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  3.84  / Min:  0.0
#
# -- Ciclo  53 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  11.52  / Min:  0.0
#
# -- Ciclo  54 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  15.35  / Min:  0.0
#
# -- Ciclo  55 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  7.68  / Min:  0.0
#
# -- Ciclo  56 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  3.84  / Min:  0.0
#
# -- Ciclo  57 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  7.68  / Min:  0.0
#
# -- Ciclo  58 --
#  Mejor Individuo: [670, 258]  { 57.58 }
#    Max:  57.58  / Promedio:  7.68  / Min:  0.0
#
# -- Ciclo  59 --
#  Mejor Individuo: [670, -653]  { 17.02 }
#    Max:  17.02  / Promedio:  1.13  / Min:  0.0
#
# -- Ciclo  60 --
#  Mejor Individuo: [670, -653]  { 17.02 }
#    Max:  17.02  / Promedio:  2.27  / Min:  0.0
#
# -- Ciclo  61 --
#  Mejor Individuo: [670, -323]  { 74.86 }
#    Max:  74.86  / Promedio:  9.53  / Min:  0.0
#
# -- Ciclo  62 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  26.34  / Min:  0.0
#
# -- Ciclo  63 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  31.33  / Min:  0.0
#
# -- Ciclo  64 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  41.87  / Min:  0.0
#
# -- Ciclo  65 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  32.01  / Min:  0.0
#
# -- Ciclo  66 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  26.28  / Min:  0.0
#
# -- Ciclo  67 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  21.29  / Min:  0.0
#
# -- Ciclo  68 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  33.14  / Min:  0.0
#
# -- Ciclo  69 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  38.16  / Min:  0.0
#
# -- Ciclo  70 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  30.02  / Min:  0.0
#
# -- Ciclo  71 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  23.9  / Min:  0.0
#
# -- Ciclo  72 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  30.73  / Min:  0.0
#
# -- Ciclo  73 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  20.47  / Min:  0.0
#
# -- Ciclo  74 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  23.9  / Min:  0.0
#
# -- Ciclo  75 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  37.58  / Min:  0.0
#
# -- Ciclo  76 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  37.58  / Min:  0.0
#
# -- Ciclo  77 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  26.19  / Min:  0.0
#
# -- Ciclo  78 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  23.92  / Min:  0.0
#
# -- Ciclo  79 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  17.09  / Min:  0.0
#
# -- Ciclo  80 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  18.25  / Min:  0.0
#
# -- Ciclo  81 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  29.25  / Min:  0.0
#
# -- Ciclo  82 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  13.69  / Min:  0.0
#
# -- Ciclo  83 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  19.36  / Min:  0.0
#
# -- Ciclo  84 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  20.49  / Min:  0.0
#
# -- Ciclo  85 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  33.02  / Min:  0.0
#
# -- Ciclo  86 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  9.16  / Min:  0.0
#
# -- Ciclo  87 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  21.69  / Min:  0.0
#
# -- Ciclo  88 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  19.39  / Min:  0.0
#
# -- Ciclo  89 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  20.53  / Min:  0.0
#
# -- Ciclo  90 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  21.66  / Min:  0.0
#
# -- Ciclo  91 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  30.89  / Min:  0.0
#
# -- Ciclo  92 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  25.36  / Min:  0.0
#
# -- Ciclo  93 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  36.35  / Min:  0.0
#
# -- Ciclo  94 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  16.58  / Min:  0.0
#
# -- Ciclo  95 --
#  Mejor Individuo: [670, 73]  { 74.52 }
#    Max:  74.52  / Promedio:  20.36  / Min:  0.0
#
# -- Ciclo  96 --
#  Mejor Individuo: [670, -102]  { 85.45 }
#    Max:  85.45  / Promedio:  17.23  / Min:  0.0
#
# -- Ciclo  97 --
#  Mejor Individuo: [670, -77]  { 84.72 }
#    Max:  84.72  / Promedio:  17.92  / Min:  0.0
#
# -- Ciclo  98 --
#  Mejor Individuo: [99, -102]  { 58.09 }
#    Max:  58.09  / Promedio:  12.4  / Min:  0.0
#
# -- Ciclo  99 --
#  Mejor Individuo: [670, 88]  { 73.23 }
#    Max:  73.23  / Promedio:  16.72  / Min:  0.0
#
# -- Ciclo  100 --
#  Mejor Individuo: [670, 88]  { 73.23 }
#    Max:  73.23  / Promedio:  15.86  / Min:  0.0
#
# -- Ciclo  101 --
#  Mejor Individuo: [279, 88]  { 67.79 }
#    Max:  67.79  / Promedio:  11.05  / Min:  0.0
#
# -- Ciclo  102 --
#  Mejor Individuo: [279, 88]  { 67.79 }
#    Max:  67.79  / Promedio:  17.98  / Min:  0.0
#
# -- Ciclo  103 --
#  Mejor Individuo: [279, 88]  { 67.79 }
#    Max:  67.79  / Promedio:  22.23  / Min:  0.0
#
# -- Ciclo  104 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  9.98  / Min:  0.0
#
# -- Ciclo  105 --
#  Mejor Individuo: [279, 88]  { 67.79 }
#    Max:  67.79  / Promedio:  19.02  / Min:  0.0
#
# -- Ciclo  106 --
#  Mejor Individuo: [99, -458]  { 44.68 }
#    Max:  44.68  / Promedio:  8.97  / Min:  0.0
#
# -- Ciclo  107 --
#  Mejor Individuo: [99, 88]  { 53.15 }
#    Max:  53.15  / Promedio:  18.5  / Min:  0.0
#
# -- Ciclo  108 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  15.97  / Min:  0.0
#
# -- Ciclo  109 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  13.98  / Min:  0.0
#
# -- Ciclo  110 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  15.97  / Min:  0.0
#
# -- Ciclo  111 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  15.97  / Min:  0.0
#
# -- Ciclo  112 --
#  Mejor Individuo: [99, -653]  { 29.95 }
#    Max:  29.95  / Promedio:  15.97  / Min:  0.0
#
# -- Ciclo  113 --
#  Mejor Individuo: [170, -150]  { 64.97 }
#    Max:  64.97  / Promedio:  14.05  / Min:  0.0
#
# -- Ciclo  114 --
#  Mejor Individuo: [99, -150]  { 57.91 }
#    Max:  57.91  / Promedio:  10.45  / Min:  0.0
#
# -- Ciclo  115 --
#  Mejor Individuo: [601, -150]  { 83.13 }
#    Max:  83.13  / Promedio:  5.54  / Min:  0.0
#
# -- Ciclo  116 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  117 --
#  Mejor Individuo: [-147, -653]  { 13.34 }
#    Max:  13.34  / Promedio:  0.89  / Min:  0.0
#
# -- Ciclo  118 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  119 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  120 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  121 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  122 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  123 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  124 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  125 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  126 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  127 --
#  Mejor Individuo: [-495, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  128 --
#  Mejor Individuo: [-641, 225]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  129 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  130 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  5.63  / Min:  0.0
#
# -- Ciclo  131 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  5.63  / Min:  0.0
#
# -- Ciclo  132 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  11.27  / Min:  0.0
#
# -- Ciclo  133 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  9.66  / Min:  0.0
#
# -- Ciclo  134 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  9.66  / Min:  0.0
#
# -- Ciclo  135 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  5.63  / Min:  0.0
#
# -- Ciclo  136 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  9.66  / Min:  0.0
#
# -- Ciclo  137 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  28.17  / Min:  0.0
#
# -- Ciclo  138 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  32.19  / Min:  0.0
#
# -- Ciclo  139 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  19.32  / Min:  0.0
#
# -- Ciclo  140 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  15.29  / Min:  0.0
#
# -- Ciclo  141 --
#  Mejor Individuo: [660, 225]  { 60.37 }
#    Max:  60.37  / Promedio:  12.07  / Min:  0.0
#
# -- Ciclo  142 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  9.66  / Min:  0.0
#
# -- Ciclo  143 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  19.58  / Min:  0.0
#
# -- Ciclo  144 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  31.57  / Min:  0.0
#
# -- Ciclo  145 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  16.9  / Min:  0.0
#
# -- Ciclo  146 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  15.29  / Min:  0.0
#
# -- Ciclo  147 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  16.9  / Min:  0.0
#
# -- Ciclo  148 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  16.9  / Min:  0.0
#
# -- Ciclo  149 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  22.53  / Min:  0.0
#
# -- Ciclo  150 --
#  Mejor Individuo: [660, -150]  { 84.5 }
#    Max:  84.5  / Promedio:  10.78  / Min:  0.0
#
# -- Ciclo  151 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  152 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  153 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  154 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  155 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  156 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  157 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  158 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  159 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  160 --
#  Mejor Individuo: [265, -150]  { 74.36 }
#    Max:  74.36  / Promedio:  4.96  / Min:  0.0
#
# -- Ciclo  161 --
#  Mejor Individuo: [265, -150]  { 74.36 }
#    Max:  74.36  / Promedio:  4.96  / Min:  0.0
#
# -- Ciclo  162 --
#  Mejor Individuo: [265, -150]  { 74.36 }
#    Max:  74.36  / Promedio:  4.96  / Min:  0.0
#
# -- Ciclo  163 --
#  Mejor Individuo: [-641, 3]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  164 --
#  Mejor Individuo: [39, -150]  { 51.94 }
#    Max:  51.94  / Promedio:  3.46  / Min:  0.0
#
# -- Ciclo  165 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  166 --
#  Mejor Individuo: [-506, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  167 --
#  Mejor Individuo: [-506, 3]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  168 --
#  Mejor Individuo: [-157, -150]  { 32.39 }
#    Max:  32.39  / Promedio:  2.16  / Min:  0.0
#
# -- Ciclo  169 --
#  Mejor Individuo: [-157, -150]  { 32.39 }
#    Max:  32.39  / Promedio:  4.32  / Min:  0.0
#
# -- Ciclo  170 --
#  Mejor Individuo: [-157, -150]  { 32.39 }
#    Max:  32.39  / Promedio:  4.32  / Min:  0.0
#
# -- Ciclo  171 --
#  Mejor Individuo: [-157, -150]  { 32.39 }
#    Max:  32.39  / Promedio:  2.16  / Min:  0.0
#
# -- Ciclo  172 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  173 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  174 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  175 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  176 --
#  Mejor Individuo: [-641, 3]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  177 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  178 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  179 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  180 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  181 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  182 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  183 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  184 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  185 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  186 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  187 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  188 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  189 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  190 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  191 --
#  Mejor Individuo: [-641, -150]  { 0.0 }
#    Max:  0.0  / Promedio:  0.0  / Min:  0.0
#
# -- Ciclo  192 --
#  Mejor Individuo: [55, -150]  { 53.53 }
#    Max:  53.53  / Promedio:  3.57  / Min:  0.0
#
# -- Ciclo  193 --
#  Mejor Individuo: [55, -150]  { 53.53 }
#    Max:  53.53  / Promedio:  3.57  / Min:  0.0
#
# -- Ciclo  194 --
#  Mejor Individuo: [55, -150]  { 53.53 }
#    Max:  53.53  / Promedio:  10.71  / Min:  0.0
#
# -- Ciclo  195 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  22.39  / Min:  0.0
#
# -- Ciclo  196 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  26.93  / Min:  0.0
#
# -- Ciclo  197 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  20.77  / Min:  0.0
#
# -- Ciclo  198 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  30.82  / Min:  0.0
#
# -- Ciclo  199 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  34.39  / Min:  0.0
#
# -- Ciclo  200 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  31.8  / Min:  0.0
#
# -- Ciclo  201 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  49.97  / Min:  0.0
#
# -- Ciclo  202 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  54.52  / Min:  0.0
#
# -- Ciclo  203 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  49.98  / Min:  0.0
#
# -- Ciclo  204 --
#  Mejor Individuo: [445, -150]  { 90.97 }
#    Max:  90.97  / Promedio:  46.95  / Min:  0.0
#
# -- Ciclo  205 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  27.26  / Min:  0.0
#
# -- Ciclo  206 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  31.8  / Min:  0.0
#
# -- Ciclo  207 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  36.34  / Min:  0.0
#
# -- Ciclo  208 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  45.43  / Min:  0.0
#
# -- Ciclo  209 --
#  Mejor Individuo: [885, -150]  { 88.52 }
#    Max:  88.52  / Promedio:  46.79  / Min:  0.0
#
# -- Ciclo  210 --
#  Mejor Individuo: [885, -150]  { 88.52 }
#    Max:  88.52  / Promedio:  55.87  / Min:  0.0
#
# -- Ciclo  211 --
#  Mejor Individuo: [885, -150]  { 88.52 }
#    Max:  88.52  / Promedio:  61.77  / Min:  0.0
#
# -- Ciclo  212 --
#  Mejor Individuo: [885, -150]  { 88.52 }
#    Max:  88.52  / Promedio:  55.87  / Min:  0.0
#
# -- Ciclo  213 --
#  Mejor Individuo: [885, -150]  { 88.52 }
#    Max:  88.52  / Promedio:  52.19  / Min:  0.0
#
# -- Ciclo  214 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  54.51  / Min:  0.0
#
# -- Ciclo  215 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  54.51  / Min:  0.0
#
# -- Ciclo  216 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  59.05  / Min:  0.0
#
# -- Ciclo  217 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  218 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  219 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  220 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  63.6  / Min:  0.0
#
# -- Ciclo  221 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  63.6  / Min:  0.0
#
# -- Ciclo  222 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  223 --
#  Mejor Individuo: [266, -150]  { 74.46 }
#    Max:  74.46  / Promedio:  68.56  / Min:  68.14
#
# -- Ciclo  224 --
#  Mejor Individuo: [266, -150]  { 74.46 }
#    Max:  74.46  / Promedio:  68.56  / Min:  68.14
#
# -- Ciclo  225 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  226 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  227 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  67.87  / Min:  64.15
#
# -- Ciclo  228 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  229 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  230 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  231 --
#  Mejor Individuo: [475, -150]  { 92.19 }
#    Max:  92.19  / Promedio:  69.74  / Min:  68.14
#
# -- Ciclo  232 --
#  Mejor Individuo: [475, -150]  { 92.19 }
#    Max:  92.19  / Promedio:  71.35  / Min:  68.14
#
# -- Ciclo  233 --
#  Mejor Individuo: [475, -150]  { 92.19 }
#    Max:  92.19  / Promedio:  72.95  / Min:  68.14
#
# -- Ciclo  234 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  235 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  68.14  / Min:  68.14
#
# -- Ciclo  236 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  67.96  / Min:  65.45
#
# -- Ciclo  237 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  67.6  / Min:  65.45
#
# -- Ciclo  238 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  67.55  / Min:  64.71
#
# -- Ciclo  239 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  64.18  / Min:  11.43
#
# -- Ciclo  240 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  52.84  / Min:  11.43
#
# -- Ciclo  241 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  58.09  / Min:  11.43
#
# -- Ciclo  242 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  45.1  / Min:  11.43
#
# -- Ciclo  243 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  45.1  / Min:  11.43
#
# -- Ciclo  244 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  48.7  / Min:  11.43
#
# -- Ciclo  245 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  63.27  / Min:  11.43
#
# -- Ciclo  246 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  67.05  / Min:  65.23
#
# -- Ciclo  247 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  66.5  / Min:  65.23
#
# -- Ciclo  248 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  66.14  / Min:  65.23
#
# -- Ciclo  249 --
#  Mejor Individuo: [202, -150]  { 68.14 }
#    Max:  68.14  / Promedio:  62.48  / Min:  0.0
#
# -- Corrida Finalizada en 250 ciclos --
#
# ** Posición Máximo Óptimo a Buscar:  [793, -127]  {  98  } **
# == Mejor Individuo de la Corrida: [750, -138]  {  93.562  }  ==

# %%
#@title MOSTRAR GRAFICO DE LA CORRIDA
plt.figure(figsize=(15,8)) 
plt.plot(ciclosPromAptitud)
plt.plot(ciclosMinAptitud)
plt.plot(ciclosMaxAptitud)
plt.title('Resultados de la Corrida')
plt.xlabel('Ciclos')
plt.ylabel('Aptitud')
plt.legend(['Promedio', 'Mínima', 'Máxima'], loc='lower right')
plt.grid(True)
plt.show()

# %%
#@title MOSTRAR GRAFICO DE POSICIONES DE LOS INDIVIDUOS CICLO x CICLO

# Librerías especiales para usar
import matplotlib as mpl
from matplotlib import animation, rc
from IPython.display import HTML

# método que se usa para generar gradiente de colores
def colorFader(c1, c2, mix=0.0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1 = np.array(mpl.colors.to_rgb(c1))
    c2 = np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

# Método que se ejecuta por cada frame para mostrar 
def updatePlot(i, ciclosPos, scat, axi, posMejorCorrida, cicloMejorCorrida):
    if axi is None or ciclosPos is None:
      return scat,

    axi.set_xlabel('Ciclo: ' + str(i), fontsize=12)
      # Si no es el último ciclo, muestra también el global
    if i<len(ciclosPos):     
      if len(ciclosPos[i])>0:          
          if MOSTRAR_HISTORICO_MOVIMIENTO:
              # Coloca nuevas posiciones correspondientes al ciclo
              # Separa las coordenadas x, y de las posiciones en el ciclo i
              X, Y = zip(*ciclosPos[i])
              ## --en Rojo: posiciones de las particulas de cada ciclo
              axi.scatter(X, Y, color='red')
          else:
              # Hace mover a las Partículas
              scat.set_offsets(ciclosPos[i])              
    
    if i>=cicloMejorCorrida:
      if posMejorCorrida is not None:
          ## --en Violeta: Mejor posición de las partículas
          if len(posMejorCorrida) == 2 and isinstance(posMejorCorrida[0], int) and  isinstance(posMejorCorrida[1], int):
              axi.scatter(posMejorCorrida[0], posMejorCorrida[1], color='violet', s=100)
          else:
              X, Y = zip(*posMejorCorrida)                      
              axi.scatter(X, Y, color='violet', s=100)

    # Devuelve una lista de "artistas" para dibujar, 
    # en este caso es sólo uno por lo que se pone una coma final
    return scat,    

# Función para preparar el gráfico          
def PrepararGrafico(mapa, MIN_ESPACIO_BUSQ, MAX_ESPACIO_BUSQ, ciclosPos, partMejorCorrida, cicloMejorCorrida, textoTitulo, textoDesc):          

    fig = plt.figure(figsize=(12,6))
    ax = fig.add_subplot(111)
    plt.close()

    ## -- en Azul: Máximos Locales (positivos)
    ## -- en Cyan: Mínimos Locales (negativos)
    ## -- en Verde: Máximo Óptimo
    for posi, vali in zip(mapa.posMaximos, mapa.valMaximos):    
      valRel = abs(vali / mapa.valMaximoGlobal) 
      if vali < 0:        
          c = colorFader('cyan', 'green', valRel) 
          ax.scatter(posi[0], posi[1], color=c)
      else:
          c = colorFader('blue', 'green', valRel) 
          ax.scatter(posi[0], posi[1], color=c)      
    ax.scatter(mapa.posMaximoGlobal[0], mapa.posMaximoGlobal[1], color='green', s=150)  

    # Define el tamaño de la figura
    ax.axis([MIN_ESPACIO_BUSQ, MAX_ESPACIO_BUSQ, MIN_ESPACIO_BUSQ, MAX_ESPACIO_BUSQ])

    # Separa las coordenadas x, y de las posiciones en el ciclo inicial
    X, Y = zip(*ciclosPos[0])
    ## --en Rojo: posiciones de las posiciones de cada ciclo
    scat = ax.scatter(X, Y, color='red')

    # Muestra título y texto debajo
    ax.set_title(textoTitulo)
    ax.set_ylabel(textoDesc, fontsize=11)

    # Luego setea la animación usando los dos métodos anteriores 
    cant = len(ciclosPos)+1
    ani = animation.FuncAnimation(fig, updatePlot, 
                                  frames=cant, interval=cant,
                                  fargs=(ciclosPos, scat, ax, partMejorCorrida, cicloMejorCorrida), 
                                  blit=True, repeat=False)
    
    return ani

# Define la configuración para el gráfico
MOSTRAR_HISTORICO_MOVIMIENTO = False
textoTitulo = "Posición de los Individuos del AG ciclo x ciclo"
textoDesc = '\n** Posición Máximo Óptimo a buscar : ' + str(mapa.posMaximoGlobal) + ' { ' +  str(mapa.valMaximoGlobal) +' } **'
textoDesc = textoDesc + '\n== Mejor Individuo: ' + str(mejorIndCorrida) + ' { ' + str(round(mejorIndCorrida.fitness.values[0], 3)) + ' } =='
textoDesc = textoDesc + '\n-- Colores:  Máximos Locales (AZUL) - Máximo Óptimo (VERDE) - '  
textoDesc = textoDesc + '\n- Partículas (ROJO) - Mejor Individuo (VIOLETA) -- ' 

# Prepara el gráfico 
ani = PrepararGrafico(mapa, MIN_ESPACIO_BUSQ, MAX_ESPACIO_BUSQ, ciclosIndiv, mejorIndCorrida, mejorIndCorrida_ciclo, textoTitulo, textoDesc)    

# Nota: esto se agega para que funcione en Google Colab
rc('animation', html='jshtml')
display(ani)

# %%
#@title EXPORTA EL GRAFICO ANTERIOR COMO UN VIDEO MP4
Exportar_Video_Animacion = False #@param {type:"boolean"}

if Exportar_Video_Animacion:
    from google.colab import files

    # Graba el gráfico anterior como un video MP4
    nomArchi = "AG Corrida.mp4"
    ani.save('/' + nomArchi)
    try: 
      files.download('/' + nomArchi)
      print('Video ' + nomArchi + ' generado, debería bajarse automaticamente como un archivo local...')
    except ValueError:
      print('Error al intentar descargar el archivo ' + nomArchi)
